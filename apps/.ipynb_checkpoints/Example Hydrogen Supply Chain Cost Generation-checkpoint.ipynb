# %% [markdown]
# # Workflow for a hydrogen infrastructure analysis on spatial scale
#
# In this application, a spatially resolved hydrogen infrastructure is modeled to analyze differen hydrogen supply chains with spatial resolution.
#
# The workflow is structured as follows:
# 1. Import relevant modules / tools / packages
# 2. Data Import and Manipulation
# 3. Prepare demand Patterns
# 4. Methodical Applications
#     4.1 Creation of Distance Matrices
#     4.2 Optimization of pipeline routing
#     4.3 Optimization of truck transmission routing
#     4.4 Optimization of truck distribution routing
# 5. Definition of supply chains
# 6. Running the supply chain model
# 7. Creating Plots and Diagrams

# %% [markdown]
# ## 1. Import relevant modules / tools

# %% [markdown]
# The main techno-economic assumptions are based on Reuß et al. (2019) https://doi.org/10.1016/j.apenergy.2019.04.064 and can be loaded with the $HIM.workflow.scenarioExample$ script

# %%
from HIM.workflow.scenarioExample import *

# %% [markdown]
# Besides that, different HIM modules have to be imported to have the full utilization available

# %%
from HIM import dataHandling as sFun
from HIM import optiSetup as optiFun
from HIM import hscTotal
from HIM import plotFunctions as pFun
from HIM.workflow import preprocFunc as preFun

# %% [markdown]
# ## 2. Data Import and Manipulation

# %% [markdown]
# To showcase the model, an example dataset is stored on the data folder of the package with randomized Production and Fueling station locations.
#
# "dataPath" is the internal storage folder of the python package. To save into a new folder, please adjust the "pathSave" variable.

# %%
dataPathExample=path.join(dataPath,"HSCExampleInputs")

# %%
pathDist= path.join(dataPathExample,"area")
pathFS = path.join(dataPathExample,"randomFuelingStations")
pathSource = path.join(dataPathExample,"randomSources")
pathGasP = path.join(dataPathExample,"GasGridPoints")
pathStreet= path.join(dataPathExample,"StreetLines")

# %% [markdown]
# ### Import Demand, Sources and Connections (streets and candidate grid)

# %%
District = sFun.import_shp(pathDist, crs=crs, name="C")
District

# %%
# Out:
#       vehicles                                           geometry  intIndex  \
# C0     42321.0  POLYGON ((527845.3891847082 6073764.748410056,...         0
# C1    107982.0  POLYGON ((577156.386489201 6029965.650990398, ...         1
# C2     96030.0  POLYGON ((623679.4040304357 5980679.433307462,...         2
# C3     40776.0  POLYGON ((566286.5920529336 5999716.891725249,...         3
# C4     77783.0  (POLYGON ((504610.3244715404 6023877.016337246...         4
# C5    112139.0  POLYGON ((614327.2170751488 5965243.470383454,...         5
# C6     98386.0  (POLYGON ((464672.0097127259 6100532.46993125,...         6
# C7    120584.0  (POLYGON ((637074.0059796812 6029267.837942884...         7
# C8    170317.0  (POLYGON ((549449.2100918085 5971854.234904454...         8
# C9     76958.0  POLYGON ((589735.0310248563 6031898.761727584,...         9
# C10   165360.0  POLYGON ((563186.8517132145 6055925.605067861,...        10
# C11   120505.0  (POLYGON ((507767.3184495669 6080680.702503703...        11
# C12   160052.0  POLYGON ((588568.2658146754 5996366.171016177,...        12
# C13    77735.0  (POLYGON ((534754.1163062018 5994099.733202477...        13
# C14   146285.0  (POLYGON ((570685.0869726874 5951348.085746824...        14
# C15   771573.0  (POLYGON ((578680.8975659665 5954281.962224303...        15
# C16   134318.0  POLYGON ((604990.9000704543 5800779.854960674,...        16
# C17    53037.0  POLYGON ((596317.4031456339 5786478.983805023,...        17
# C5      C5
# C6      C6
# C7      C7
# C8      C8
# C9      C9
# C10    C10
# C11    C11
# C12    C12
# C13    C13
# C14    C14
# C15    C15
# C16    C16
# C17    C17
# C18    C18
# C19    C19
# C20    C20
# C21    C21
# C22    C22
# C23    C23
# C24    C24
# C25    C25
# C26    C26
# C27    C27
# C28    C28
# C29    C29
# ...    ...
# C370  C370
# C371  C371
# C372  C372
# C373  C373
# C374  C374
# C375  C375
# C376  C376
# C377  C377
# C378  C378
# C379  C379
# C380  C380
# C381  C381
# C382  C382
# C383  C383
# C384  C384
# C385  C385
# C386  C386
# C387  C387
# C388  C388
# C389  C389
# C390  C390
# C391  C391
# C392  C392
# C393  C393
# C394  C394
# C395  C395
# C396  C396
# C397  C397
# C398  C398
# C399  C399
#
# [400 rows x 4 columns]

# %%
Fueling = sFun.import_shp(pathFS, crs=crs, name="F")
Fueling
# Out:
#        BAB  GEBIET                                     geometry  intIndex  \
# F0       0       2  POINT (527858.2270696156 6073091.160381753)         0
# F1       1       3  POINT (524368.9962398433 6068946.055854723)         1
# F2       0       3  POINT (524614.3183384173 6068346.522265787)         2
# F3       0       1  POINT (527813.5521552893 6070579.530434046)         3
# F4       1       2  POINT (527582.5489159778 6068969.253984731)         4
# F5       1       3   POINT (530552.9418652141 6074343.88696268)         5
# F6       0       1   POINT (528777.7504143756 6070085.11406594)         6
# F7       0       3  POINT (527025.3325094135 6067585.078576482)         7
# F8       1       1  POINT (528085.2618781917 6068308.715563182)         8
# F9       1       1  POINT (528751.0997934908 6068442.848543459)         9
# F10      0       3   POINT (572372.8908725039 6016471.50451075)        10
# F11      0       2  POINT (576602.9592259468 6028190.265290914)        11
# F12      0       1   POINT (568592.966023544 6019373.739925355)        12
# F13      1       1  POINT (572033.5584526355 6016670.991361176)        13
# F14      0       2  POINT (577361.7359522699 6021561.970123203)        14
# F15      1       1  POINT (572284.5711860039 6017856.061837444)        15
# F16      0       3   POINT (575113.1606162911 6014437.86686301)        16
# F17      0       1  POINT (576686.2447668022 6013212.459744303)        17
# F18      1       3  POINT (572326.9147657262 6013352.307769148)        18
# F19      1       3   POINT (572439.3561931219 6016803.71353221)        19
# F20      1       1  POINT (608294.9079460532 5967856.786320135)        20
# F21      1       1   POINT (611458.658075685 5960978.616062222)        21
# F22      0       2  POINT (613781.2370307611 5975059.670729697)        22
# F23      0       1  POINT (610216.9894951425 5972271.591494063)        23
# F24      1       1  POINT (608713.7121098369 5967048.566225578)        24
# F25      1       1  POINT (620883.5486963043 5978297.013160143)        25
# F26      0       2  POINT (619244.9897538623 5977245.696890928)        26
# F27      0       3   POINT (606721.441469423 5971592.915556622)        27
# F28      1       2  POINT (611810.3586416757 5973078.585897617)        28
# F29      0       1   POINT (606552.0052480455 5972033.64070903)        29
# ...    ...     ...                                          ...       ...
# F3970    1       2   POINT (684546.106642441 5621616.932775449)      3970
# F3971    1       3  POINT (708455.5001947088 5596194.461876009)      3971
# F3972    1       3  POINT (693198.7971448577 5630643.754623169)      3972
# F3973    0       1    POINT (676845.3754078548 5619183.8215949)      3973
# G1239  1239  POINT (870353.0870717985 5945877.555857686)      1239  G1239
# G1240  1240  POINT (880353.0870717984 6035877.555857686)      1240  G1240
# G1241  1241  POINT (890353.0870717983 6045877.555857684)      1241  G1241
# G1242  1242  POINT (900353.0870717985 6055877.555857685)      1242  G1242
# G1243  1243  POINT (910353.0870717985 6065877.555857684)      1243  G1243
# G1244  1244  POINT (920353.0870717985 6075877.555857685)      1244  G1244
# G1245  1245  POINT (930353.0870717986 6085877.555857685)      1245  G1245
# G1246  1246  POINT (940353.0870717984 6095877.555857686)      1246  G1246
# G1247  1247  POINT (950353.0870717985 6105877.555857685)      1247  G1247
# G1248  1248  POINT (960353.0870717985 6115877.555857684)      1248  G1248
# G1249  1249  POINT (970353.0870717987 6125877.555857684)      1249  G1249
# G1250  1250  POINT (880353.0870717984 6035877.555857686)      1250  G1250
# G1251  1251  POINT (890353.0870717985 6025877.555857684)      1251  G1251
# G1252  1252  POINT (900353.0870717985 6015877.555857685)      1252  G1252
# G1253  1253  POINT (910353.0870717987 6005877.555857685)      1253  G1253
# G1254  1254  POINT (920353.0870717983 5995877.555857685)      1254  G1254
# G1255  1255  POINT (930353.0870717985 5985877.555857684)      1255  G1255
# G1256  1256  POINT (940353.0870717985 5975877.555857685)      1256  G1256
# G1257  1257  POINT (950353.0870717985 5965877.555857684)      1257  G1257
# G1258  1258  POINT (960353.0870717984 5955877.555857685)      1258  G1258
# G1259  1259  POINT (970353.0870717982 5945877.555857686)      1259  G1259
#
# [1260 rows x 4 columns]

# %%
(distStreet, StreetsPointsNew) = preFun.importDLMStreets(pathStreet, speed, crs)
distStreet
# Out:
#                              inputID    targetID   distance  weightedDistance  \
# (Street0, Street1)           Street0     Street1  10.000000         10.000000
# (Street0, Street2)           Street0     Street2  10.000000         10.000000
# (Street0, Street3)           Street0     Street3  14.142136         14.142136
# (Street0, Street4)           Street0     Street4  14.142136         14.142136
# (Street1, Street5)           Street1     Street5  10.000000         10.000000
# (Street1, Street3)           Street1     Street3  10.000000         10.000000
# (Street1, Street6)           Street1     Street6  14.142136         14.142136
# (Street1, Street7)           Street1     Street7  14.142136         14.142136
# (Street5, Street8)           Street5     Street8  10.000000         10.000000
# (Street5, Street6)           Street5     Street6  10.000000         10.000000
# (Street5, Street9)           Street5     Street9  14.142136         14.142136
# (Street5, Street10)          Street5    Street10  14.142136         14.142136
# (Street8, Street11)          Street8    Street11  10.000000         10.000000
# (Street8, Street9)           Street8     Street9  10.000000         10.000000
# (Street8, Street12)          Street8    Street12  14.142136         14.142136
# (Street8, Street13)          Street8    Street13  14.142136         14.142136
# (Street11, Street14)        Street11    Street14  10.000000         10.000000
# (Street11, Street12)        Street11    Street12  10.000000         10.000000
# (Street11, Street15)        Street11    Street15  14.142136         14.142136
# (Street11, Street16)        Street11    Street16  14.142136         14.142136
# (Street14, Street17)        Street14    Street17  10.000000         10.000000
# (Street14, Street15)        Street14    Street15  10.000000         10.000000
# (Street14, Street18)        Street14    Street18  14.142136         14.142136
# (Street14, Street19)        Street14    Street19  14.142136         14.142136
# (Street17, Street20)      0.333333
# (Street17, Street18)      0.333333
# (Street17, Street21)      0.471405
# (Street17, Street22)      0.471405
# (Street20, Street23)      0.333333
# (Street20, Street21)      0.333333
# ...                            ...
# (Street5798, Street5865)  0.471405
# (Street5798, Street5733)  0.471405
# (Street5799, Street5800)  0.333333
# (Street5799, Street5865)  0.333333
# (Street5799, Street5866)  0.471405
# (Street5799, Street5734)  0.471405
# (Street5800, Street5801)  0.333333
# (Street5800, Street5866)  0.333333
# (Street5800, Street5867)  0.471405
# (Street5800, Street5735)  0.471405
# (Street5801, Street5802)  0.333333
# (Street5801, Street5867)  0.333333
# (Street5801, Street5868)  0.471405
# (Street5801, Street5736)  0.471405
# (Street5802, Street5803)  0.333333
# (Street5802, Street5868)  0.333333
# (Street5802, Street5869)  0.471405
# (Street5802, Street5737)  0.471405
# (Street5803, Street5804)  0.333333
# (Street5803, Street5869)  0.333333
# (Street5803, Street5870)  0.471405
# (Street5803, Street5738)  0.471405
# (Street5804, Street5805)  0.333333
# (Street5804, Street5870)  0.333333
# (Street5804, Street5871)  0.471405
# (Street5804, Street5739)  0.471405
# (Street5805, Street5806)  0.333333
# (Street5805, Street5871)  0.333333
# (Street5805, Street5872)  0.471405
# (Street5805, Street5740)  0.471405
#
# [22620 rows x 5 columns]

# %% [markdown]
# For better visualization of the results, we define a standard plotting routine for geospatial plots

# %%
def plot_shape(figsize=(7,10), facecolor="white"):
    unary=gpd.GeoSeries([District.unary_union])
    ax=unary.plot(facecolor=facecolor, figsize=figsize)
    ax.xaxis.set_ticklabels(["" for x in ax.xaxis.get_ticklabels()])
    ax.yaxis.set_ticklabels(["" for x in ax.yaxis.get_ticklabels()])
    ax.axis("off")
    ax.set_aspect("equal")
    return ax

# %% [markdown]
# ## 3. Prepare demand Patterns

# %% [markdown]
# First, we match the fueling station locations with the district polygons

# %%
spatial_index=Fueling.sindex
for (areaID, areaValue) in District.iterrows():
    possible_matches_index = list(spatial_index.intersection(areaValue["geometry"].bounds))
    possible_matches = Fueling.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.intersects(areaValue["geometry"])]
    Fueling.loc[precise_matches.index,"ID_C"]=areaID
    District.loc[areaID, "nFuelStat"]=len(precise_matches.index)

# %%
ax=plot_shape()
District.boundary.plot(ax=ax, color="black", alpha=0.5)
Fueling.plot(ax=ax, marker=".", markersize=5)
plt.show()

# %% [markdown]
# Second, we prepare a Point-Dataframe by creating the centroids of each polygon area. Afterwards, we calculate the average hydrogen demand per area based on the penetration rate and the existing vehicle distribution. The penetration rate has to be defined in advance and represents the share of FCEV compared to the total fleet size.

# %%
penetration=0.25

# %%
Centroid=District.copy()
Centroid.geometry=Centroid.centroid
Centroid["FCEV"]=Centroid["vehicles"]*penetration
Centroid["H2Demand_kt"]=Centroid["FCEV"]*specificDemand*mileage*1e-6

# %% [markdown]
# Third, we calculate the number of fueling stations necessary in each district by utilizing the demand of each district and comparing it with the target fueling station size

# %%
fuelingMax_kt_a=fuelingMax_kg_d/1e6*365
Centroid["minFS"]=np.ceil(Centroid["H2Demand_kt"]/fuelingMax_kt_a)
Centroid["realFS"]=Centroid["nFuelStat"]
Centroid["H2Demand_kt_F"]= Centroid["H2Demand_kt"]/Centroid["minFS"]
Centroid.loc[Centroid["minFS"]==0,["H2Demand_kt_F", "H2Demand_kt"]]=0
District["H2Demand_kt"]=Centroid["H2Demand_kt"].values
totalH2Demand=Centroid["H2Demand_kt"].sum()

# %%
ax=plot_shape()
District.plot(column="H2Demand_kt", ax=ax)
plt.show()

# %% [markdown]
# then, we select the fueling stations out of the potential locations

# %%
FuelingNew=preFun.getChosenStations(Fueling=Fueling, Centroid=Centroid, weightFtoF=weightFtoF)

# %%
ax=plot_shape()
FuelingNew.plot(ax=ax, marker=".", markersize=5)
plt.show()

# %% [markdown]
# ### Prepare source capacity

# %% [markdown]
# For the sources, we have to set the capacity. To simplify it for this example, we set the total hydrogen demand as maximal capacity.

# %%
Source["H2ProdCap_kt"]=totalH2Demand

# %%
ax=plot_shape()
Source.plot(ax=ax, marker="*", markersize=30)
plt.show()

# %% [markdown]
# ## Grid data

# %% [markdown]
# For the street grid data, the exemplary dummy values are equally distributed points

# %%
ax=plot_shape()
StreetsPointsNew.plot(ax=ax, marker=".")
plt.show()

# %% [markdown]
# The dummy values for the existing natural gas are as well fixed data points

# %%
ax=plot_shape()
NGGridPoint.plot(ax=ax, marker=".")
plt.show()

# %% [markdown]
# ### Clustering

# %% [markdown]
# To avoid the overestimation of transmission pipelines, we cluster the fueling stations and separate them from political boundaries

# %%
if clustering:
    Cluster=sFun.createCluster(FuelingNew, clusterSize)
    Cluster.crs=Centroid.crs
    FuelingNew["weightedDistance"]=[weightFtoF[values["areaID"]]*values["distToCl"] for key, values in FuelingNew.iterrows()]
else:
    Cluster=Centroid.copy()
    FuelingNew["distToCl"]=FuelingNew["distToC"]
    FuelingNew["ClusterID"]=FuelingNew["ID_C"]

# %% [markdown]
# # 4. Methods

# %% [markdown]
# ## 4.1 Methods - Distance Matrices generation

# %% [markdown]
# For pipeline: different matrices necessary compared to the truck routing --> potential network + weight factor!

# %%
#Prepare coordinates
pipeCoords=Cluster.geometry.append(Source.geometry).append(NGGridPoint.geometry).append(FuelingNew.geometry)
truckCoords=Source.geometry.append(FuelingNew.geometry).append(StreetsPointsNew.geometry).append(Cluster.geometry)

# %% [markdown]
# if the gas grid is available as linestring data and know for usage, the distGtoG can be created directly from the gas grid data without setting up a new matrix. SInce we have just points give, we create the distance matrix via euclidian distances of near neighbours

# %%
distGtoG=sFun.selfDistMatrix(NGGridPoint, weight=1.0, kNN=4)

# %%
distMatTruck, distMatTruck2, distMatPipeline=preFun.getDistanceMatrices(Cluster,
                                                                        Source,
                                                                        FuelingNew,
                                                                        NGGridPoint,
                                                                        StreetsPointsNew,
                                                                        distStreet,distGtoG,
                                                                        weightFtoF,
                                                                        detourFactorTruck,
                                                                        beeline,
                                                                        speed,
                                                                        clustering=clustering,
                                                                        clusterSize=clusterSize,
                                                                        kNN=5,
                                                                        kNNGas=5)

# %% [markdown]
# ## 4.2 Optimization of Pipeline Routing

# %% [markdown]
# Initializing the graph and adding nodes/edges with empty capacity, maximum production, real production and real demand. Afterwards, we apply the maximum capacity and the demand of the fueling stations to the nodes.

# %%
GraphPipeline=optiFun.PipeNetWork()
GraphPipeline.initializeEdges(distMatPipeline)

nx.set_node_attributes(GraphPipeline, "productionMax", Source.H2ProdCap_kt.to_dict())
nx.set_node_attributes(GraphPipeline, "demand", FuelingNew["H2Demand_kt_F"].to_dict())

# %% [markdown]
# If our Graph is ready, we have to decide, which solving options we want to choose. For this example, we choose to use a linear representation of the pipeline flow-cost relation to select the topolgy

# %%
GraphPipeline.initOpti(linear=True)

# %% [markdown]
# After the initialization, we can run the model

# %%
GraphPipeline.optModel()
# Out:
# Academic license - for non-commercial use only
# Read LP format model from file C:\Alles\sciebo\Python\HIM\apps\tmpavtmqdxa.pyomo.lp
# Reading time = 0.71 seconds
# x98222: 41858 rows, 98222 columns, 227360 nonzeros
# Changed value of parameter MIPgap to 0.005
#    Prev: 0.0001  Min: 0.0  Max: 1e+100  Default: 0.0001
# Changed value of parameter timeLimit to 2000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter logfile to GurobiLog.txt
#    Prev: gurobi.log  Default:
# Changed value of parameter threads to 7
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter Heuristics to 0.5
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Optimize a model with 41858 rows, 98222 columns and 227360 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 5e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 37582 rows and 58564 columns
# Presolve time: 0.34s
# Presolved: 4276 rows, 39658 columns, 79306 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.982e+04
#  Factor NZ  : 6.042e+04 (roughly 18 MBytes of memory)
#  Factor Ops : 9.890e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.84473352e+07 -3.51963724e+05  4.70e+01 0.00e+00  1.45e+04     0s
#    1   4.46903587e+07  7.86488297e+02  6.26e-01 1.23e+01  1.60e+03     0s
#    2   7.55929803e+06  7.37960863e+04  1.61e-02 1.14e+00  1.99e+02     0s
#    3   1.35435734e+06  1.30250346e+05  2.09e-03 2.55e-01  3.14e+01     0s
#    4   5.36223558e+05  1.63461638e+05  5.51e-04 1.11e-01  9.49e+00     0s
#    5   3.10953649e+05  1.89153047e+05  1.67e-04 4.68e-02  3.09e+00     1s
#    6   2.52021083e+05  2.01835640e+05  6.37e-05 2.49e-02  1.27e+00     1s
#    7   2.34307060e+05  2.09126436e+05  3.08e-05 1.27e-02  6.39e-01     1s
#
# Barrier performed 7 iterations in 0.56 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 6353 iterations and 0.56 seconds
# Optimal objective  2.155206647e+05

# %% [markdown]
# During the postprocessing, we calculate the costs based on a quadratic diameter-cost relation

# %%
#Extract results
productionPipeline=GraphPipeline.getProductionNodes()
resultsEdgesPipeline=GraphPipeline.getEdgesAsGpd(pipeCoords, "pipeline")
Source["pipe_kt_a"]=productionPipeline
Source["pipe_kg_d"]=Source["pipe_kt_a"]*1e6/365

# %% [markdown]
# ## 4.3 Optimization of Truck Transmission Routing

# %% [markdown]
# Similar to the pipeline routing, we have to create first a Graph of the model

# %%
GraphTruck=optiFun.PipeNetWork()
GraphTruck.initializeEdges(distMatTruck)

nx.set_node_attributes(GraphTruck, "productionMax", Source.H2ProdCap_kt.to_dict())
nx.set_node_attributes(GraphTruck, "demand", FuelingNew["H2Demand_kt_F"].to_dict())

# %% [markdown]
# We reduce the network size since especially streets grids have a high resolution with lots of single nodes to improve the solving performance

# %%
GraphTruck.reduceNetworkSize()

# %% [markdown]
# Next, we initialize the optimization by defining the weight. Here, we use the travelled "time" of each edge as option. However, we can as well use e.g. costs or distance, in case the graph knows the values for it-

# %%
#Initializing the optimization
GraphTruck.initOptiTruck(weight=weight)

# %% [markdown]
# Next step: Running the model

# %%
GraphTruck.optModel()
# Out:
# Academic license - for non-commercial use only
# Read LP format model from file C:\Alles\sciebo\Python\HIM\apps\tmpbr43olco.pyomo.lp
# Reading time = 0.39 seconds
# x90406: 46871 rows, 90406 columns, 207599 nonzeros
# Changed value of parameter MIPgap to 0.005
#    Prev: 0.0001  Min: 0.0  Max: 1e+100  Default: 0.0001
# Changed value of parameter timeLimit to 2000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter logfile to GurobiLog.txt
#    Prev: gurobi.log  Default:
# Changed value of parameter threads to 7
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter Heuristics to 0.5
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Optimize a model with 46871 rows, 90406 columns and 207599 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-03, 5e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 41131 rows and 45554 columns
# Presolve time: 0.16s
# Presolved: 5740 rows, 44852 columns, 89694 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.242e+04
#  Factor NZ  : 2.071e+05 (roughly 20 MBytes of memory)
#  Factor Ops : 1.261e+07 (less than 1 second per iteration)
#  Threads    : 5
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.68406564e+05 -2.04180774e+03  2.59e+01 0.00e+00  5.83e+01     0s
#    1   3.17563942e+05  7.08360288e+02  6.46e-01 7.77e-16  7.06e+00     0s
#    2   2.40799913e+04  1.55632465e+03  3.92e-02 8.33e-16  5.02e-01     0s
#    3   7.68652488e+03  3.71357175e+03  4.05e-03 2.89e-15  8.86e-02     0s
#    4   5.95784707e+03  4.24405370e+03  1.53e-03 2.55e-15  3.82e-02     0s
#    5   5.50875822e+03  4.46128939e+03  9.53e-04 2.66e-15  2.33e-02     0s
#    6   5.16081122e+03  4.57198326e+03  4.88e-04 2.66e-15  1.31e-02     0s
#    7   4.99406092e+03  4.66433996e+03  2.68e-04 2.78e-15  7.35e-03     0s
#    8   4.89371812e+03  4.71043817e+03  1.43e-04 2.78e-15  4.09e-03     0s
#    9   4.83350767e+03  4.73921595e+03  6.53e-05 2.78e-15  2.10e-03     0s
#   10   4.81062324e+03  4.75645691e+03  3.72e-05 2.55e-15  1.21e-03     0s
#   11   4.79364969e+03  4.76522573e+03  1.68e-05 3.22e-15  6.34e-04     0s
#   12   4.78444280e+03  4.77242681e+03  6.72e-06 2.61e-15  2.68e-04     0s
#   13   4.77845516e+03  4.77788316e+03  8.73e-08 1.89e-15  1.28e-05     0s
#   14   4.77814875e+03  4.77811070e+03  8.16e-09 1.78e-15  8.48e-07     0s
#
# Barrier performed 14 iterations in 0.42 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 10814 iterations and 0.43 seconds
# Optimal objective  4.778115687e+03

# %% [markdown]
# And finally, catching the results from the optimization

# %%
resultsTruckNodes=GraphTruck.getProductionNodes()
resultsEdgesTruck=GraphTruck.getEdgesAsGpd(truckCoords, "truck")
#%%
Source["truck_kt_a"]=resultsTruckNodes
Source["truck_kg_d"]=Source["truck_kt_a"]*1e6/365
resultsEdgesTruck["edge"]=[not ("Street" in x[0] and "Street" in x[1]) for x in resultsEdgesTruck.index]

# %% [markdown]
# ## 4.4 Optimization of Truck Distribution Routing

# %% [markdown]
# Since we want to have the same system for the distribution option for pipeline/trailer systems, we need to calculate the truck optimization again.

# %%
GraphTruck2=optiFun.PipeNetWork()
GraphTruck2.initializeEdges(distMatTruck2)

nx.set_node_attributes(GraphTruck2, "productionMax", Cluster.H2Demand_kt.to_dict())
nx.set_node_attributes(GraphTruck2, "demand", FuelingNew["H2Demand_kt_F"].to_dict())

GraphTruck2.reduceNetworkSize()

GraphTruck2.initOptiTruck(weight=weight)

GraphTruck2.optModel()

resultsEdgesTruck2=GraphTruck2.getEdgesAsGpd(truckCoords, "truck")
resultsEdgesTruck2["H2Demand_kg_d_F"]=resultsEdgesTruck2["capacity"]*1e6/365

resultsEdgesTruck2["edge"]=[not ("Street" in x[0] and "Street" in x[1]) for x in resultsEdgesTruck2.index]
# Out:
# Academic license - for non-commercial use only
# Read LP format model from file C:\Alles\sciebo\Python\HIM\apps\tmptg87ip0l.pyomo.lp
# Reading time = 0.36 seconds
# x90534: 46967 rows, 90534 columns, 207887 nonzeros
# Changed value of parameter MIPgap to 0.005
#    Prev: 0.0001  Min: 0.0  Max: 1e+100  Default: 0.0001
# Changed value of parameter timeLimit to 2000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter logfile to GurobiLog.txt
#    Prev: gurobi.log  Default:
# Changed value of parameter threads to 7
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Changed value of parameter Heuristics to 0.5
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Optimize a model with 46967 rows, 90534 columns and 207887 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-03, 5e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 5e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 41227 rows and 45650 columns
# Presolve time: 0.17s
# Presolved: 5740 rows, 44884 columns, 89726 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.242e+04
#  Factor NZ  : 2.071e+05 (roughly 20 MBytes of memory)
#  Factor Ops : 1.261e+07 (less than 1 second per iteration)
#  Threads    : 5
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.16801013e+05  1.54113004e+02  7.94e+00 1.11e-16  7.01e+00     0s
#    1   5.82592102e+04  5.29977240e+02  2.12e+00 4.44e-16  1.29e+00     0s
#    2   8.67031219e+03  7.93305312e+02  2.62e-01 1.15e-14  1.75e-01     0s
#    3   2.78997818e+03  1.10784861e+03  4.75e-02 7.99e-15  3.75e-02     0s
#    4   1.80517923e+03  1.26835853e+03  1.32e-02 4.44e-15  1.20e-02     0s
#    5   1.54977708e+03  1.33624037e+03  4.67e-03 4.00e-15  4.75e-03     0s
#    6   1.46355169e+03  1.36021193e+03  2.08e-03 2.66e-15  2.30e-03     0s
#    7   1.41563556e+03  1.37251888e+03  7.14e-04 3.11e-15  9.60e-04     0s
#    8   1.39898433e+03  1.38096652e+03  2.62e-04 1.78e-15  4.01e-04     0s
#    9   1.39060884e+03  1.38590545e+03  6.21e-05 1.78e-15  1.05e-04     0s
#   10   1.38842549e+03  1.38761782e+03  9.03e-06 4.00e-15  1.80e-05     0s
#   11   1.38805906e+03  1.38795490e+03  1.66e-06 4.00e-15  2.32e-06     0s
#   12   1.38799054e+03  1.38796303e+03  4.15e-07 4.44e-15  6.13e-07     0s
#   13   1.38796736e+03  1.38796527e+03  2.67e-08 3.11e-15  4.65e-08     0s
#   14   1.38796551e+03  1.38796535e+03  2.08e-08 1.78e-15  3.47e-09     0s
#   15   1.38796536e+03  1.38796536e+03  5.63e-10 1.33e-15  3.51e-12     0s
#
# Barrier solved model in 15 iterations and 0.41 seconds
# Optimal objective 1.38796536e+03
#
# Crossover log...
#
#        0 DPushes remaining with DInf 1.3788970e-13                 0s
#
#     1725 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.2134738e-13      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4598    1.3879654e+03   0.000000e+00   0.000000e+00      1s
#
# Solved with barrier
# Solved in 4598 iterations and 0.54 seconds
# Optimal objective  1.387965363e+03

# %% [markdown]
# # 5. Definition of supply chains

# %% [markdown]
# First, we have to design the pathways

# %%
hscPathways={}
hscPathways["pipeline"]=[["Electrolyzer","None","Compressor", "GH2-Cavern","None","Compressor","Pipeline","Compressor","GH2-Truck","GH2 (Trailer)"],
                         ["Electrolyzer","None","Compressor", "GH2-Cavern","None","Compressor","Pipeline","None","Pipeline","GH2 (Pipeline)"]]

hscPathways["truck"]=[["Electrolyzer","None","Compressor", "GH2-Cavern","None","Compressor","GH2-Truck","None","None","GH2 (Trailer)"],
                      ["Electrolyzer","None","Compressor", "GH2-Cavern","None","Liquefaction","LH2-Truck","None","None","LH2"],
                      ["Electrolyzer","None","Compressor", "GH2-Cavern","None","Hydrogenation","LOHC-Truck","None","None","LOHC (NG)"],
                      ["Electrolyzer","Liquefaction","None", "LH2-Tank","None","None","LH2-Truck","None","None","LH2"],
                      ["Electrolyzer","Hydrogenation","None", "LOHC-Tank","None","None","LOHC-Truck","None","None","LOHC (NG)"]]

# %% [markdown]
# Since we have two transport system, we have to divide between transmission and distribution for all options and set the right dataframe

# %%
pipelineDistance=[resultsEdgesPipeline[resultsEdgesPipeline["distribution"]==False],
                  resultsEdgesPipeline[resultsEdgesPipeline["distribution"]]]

truckDistance=[resultsEdgesTruck,
               resultsEdgesTruck2]

sourceDf={"pipeline":Source["pipe_kg_d"],
          "truck":Source["truck_kg_d"]}

# %% [markdown]
# # 6. Running the supply chain model

# %% [markdown]
# Finally, we can run the Resultmanager

# %%
Results={}
i=0
for hscPathwayType in sorted(hscPathways.keys()):
    listCapacities=[sourceDf[hscPathwayType],
                    sourceDf[hscPathwayType],
                    sourceDf[hscPathwayType],
                    sourceDf[hscPathwayType],
                    sourceDf[hscPathwayType],
                    sourceDf[hscPathwayType],
                    resultsEdgesTruck["capacity"].values*1e6/365,
                    Cluster["H2Demand_kt"]*1e6/365,
                    resultsEdgesTruck2["H2Demand_kg_d_F"],
                    FuelingNew["H2Demand_kg_d_F"]]
    for listHSC in hscPathways[hscPathwayType]:
        cumCost=0

        Results[i]=hscTotal.HSC(listHSC,
                                 dfTable,
                                 listCapacities,
                                 totalH2Demand*1e6,
                                 truckDistance=truckDistance,
                                 pipelineDistance=pipelineDistance,
                                 targetCars=0,
                                 beeline=beeline)

        Results[i].calcHSC(cumCost=cumCost)
        display(Results[i].dfHSCRes)
        i+=1
# Out:
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.7002
# Connector2  0.0375  0.0118   0.0040   0.0216  1.021262e+08   3.7377
# Storage     0.2064  0.1684   0.0379   0.0000  1.914200e+09   3.9440
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.9440
# Connector4  0.0439  0.0051   0.0017   0.0371  4.406916e+07   3.9879
# Transport1  0.1906  0.1653   0.0253   0.0000  1.990021e+09   4.1786
# Connector5  0.1310  0.0279   0.0095   0.0936  2.408675e+08   4.3095
# Transport2  0.5818  0.3017   0.2331   0.0471  2.163466e+09   4.8914
# Station     1.5038  1.0208   0.2758   0.2073  7.215221e+09   6.3952
#
#                technology    nTrucks  pipeLength    Loss  electricityRES  \
# Production   Electrolyzer     0.0000      0.0000  0.0000         47.6000
# Connector1           None     0.0000      0.0000  1.0000          0.0000
# Connector2     Compressor     0.0000      0.0000  1.0015          0.2675
# Storage        GH2-Cavern     0.0000      0.0000  1.0000          0.0000
# Connector3           None     0.0000      0.0000  1.0000          0.0000
# Connector4     Compressor     0.0000      0.0000  1.0050          0.0000
# Transport1       Pipeline     0.0000   5108.7861  1.0000          0.0000
# Connector5     Compressor     0.0000      0.0000  1.0050          0.0000
# Transport2      GH2-Truck  2638.3732      0.0000  1.0000          0.0000
# Station     GH2 (Trailer)  4158.0000      0.0000  1.0050          0.0000
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production           0.0000         0.0  0.0000        1.0166
# Connector1           0.0000         0.0  0.0000        1.0166
# Connector2           0.0000         0.0  0.0000        1.0151
# Storage              0.0000         0.0  0.0000        1.0151
# Connector3           0.0000         0.0  0.0000        1.0151
# Connector4           0.2570         0.0  0.0000        1.0100
# Transport1           0.0000         0.0  0.0000        1.0100
# Connector5           1.0979         0.0  0.0000        1.0050
# Transport2           0.0000         0.0  0.2008        1.0050
# Station              1.6000         0.0  0.0000        1.0000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              174.2042
# Connector1               0.0000                0.0000
# Connector2               0.0000                0.9775
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.0317                1.3085
# Transport1               0.0000                0.0000
# Connector5               0.1346                5.5609
# Transport2               0.0642                0.8717
# Station                  0.1952                8.0640
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.7002
# Connector2  0.0375  0.0118   0.0040   0.0216  1.021262e+08   3.7377
# Storage     0.2064  0.1684   0.0379   0.0000  1.914200e+09   3.9440
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.9440
# Connector4  0.0439  0.0051   0.0017   0.0371  4.406916e+07   3.9879
# Transport1  0.1906  0.1653   0.0253   0.0000  1.990021e+09   4.1786
# Connector5  0.0000  0.0000   0.0000   0.0000  0.000000e+00   4.1786
# Transport2  3.3588  2.8721   0.4867   0.0000  3.457415e+10   7.5374
# Station     1.4282  0.8800   0.2953   0.2529  5.961254e+09   8.9656
#
#                 technology  nTrucks  pipeLength    Loss  electricityRES  \
# Production    Electrolyzer      0.0      0.0000  0.0000         47.6000
# Connector1            None      0.0      0.0000  1.0000          0.0000
# Connector2      Compressor      0.0      0.0000  1.0015          0.2675
# Storage         GH2-Cavern      0.0      0.0000  1.0000          0.0000
# Connector3            None      0.0      0.0000  1.0000          0.0000
# Connector4      Compressor      0.0      0.0000  1.0050          0.0000
# Transport1        Pipeline      0.0   5108.7861  1.0000          0.0000
# Connector5            None      0.0      0.0000  1.0000          0.0000
# Transport2        Pipeline      0.0  98262.9360  1.0000          0.0000
# Station     GH2 (Pipeline)      0.0      0.0000  1.0050          0.0000
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production            0.000         0.0     0.0        1.0115
# Connector1            0.000         0.0     0.0        1.0115
# Connector2            0.000         0.0     0.0        1.0100
# Storage               0.000         0.0     0.0        1.0100
# Connector3            0.000         0.0     0.0        1.0100
# Connector4            0.257         0.0     0.0        1.0050
# Transport1            0.000         0.0     0.0        1.0050
# Connector5            0.000         0.0     0.0        1.0050
# Transport2            0.000         0.0     0.0        1.0050
# Station               2.000         0.0     0.0        1.0000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              173.3375
# Connector1               0.0000                0.0000
# Connector2               0.0000                0.9727
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.0315                1.3020
# Transport1               0.0000                0.0000
# Connector5               0.0000                0.0000
# Transport2               0.0000                0.0000
# Station                  0.2440               10.0800
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.7002
# Connector2  0.0379  0.0121   0.0042   0.0216  1.047711e+08   3.7381
# Storage     0.2172  0.1773   0.0399   0.0000  2.014800e+09   3.9553
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.9553
# Connector4  0.1138  0.0160   0.0055   0.0923  1.381965e+08   4.0691
# Transport   1.3215  0.6540   0.5055   0.1620  4.690669e+09   5.3906
# Connector5  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.3906
# Connector6  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.3906
# Station     1.5063  1.0208   0.2758   0.2098  7.215221e+09   6.8969
#
#                technology    nTrucks  pipeLength    Loss  electricityRES  \
# Production   Electrolyzer     0.0000           0  0.0000         47.6000
# Connector1           None     0.0000           0  1.0000          0.0000
# Connector2     Compressor     0.0000           0  1.0015          0.2675
# Storage        GH2-Cavern     0.0000           0  1.0000          0.0000
# Connector3           None     0.0000           0  1.0000          0.0000
# Connector4     Compressor     0.0000           0  1.0050          0.0000
# Transport       GH2-Truck  5720.3281           0  1.0000          0.0000
# Connector5           None     0.0000           0  1.0000          0.0000
# Connector6           None     0.0000           0  1.0000          0.0000
# Station     GH2 (Trailer)  4158.0000           0  1.0050          0.0000
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production            0.000         0.0  0.0000        1.0115
# Connector1            0.000         0.0  0.0000        1.0115
# Connector2            0.000         0.0  0.0000        1.0100
# Storage               0.000         0.0  0.0000        1.0100
# Connector3            0.000         0.0  0.0000        1.0100
# Connector4            1.193         0.0  0.0000        1.0050
# Transport             0.000         0.0  0.6912        1.0050
# Connector5            0.000         0.0  0.0000        1.0050
# Connector6            0.000         0.0  0.0000        1.0050
# Station               1.600         0.0  0.0000        1.0000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              173.3375
# Connector1               0.0000                0.0000
# Connector2               0.0000                0.9726
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.1463                6.0426
# Transport                0.2209                3.0008
# Connector5               0.0000                0.0000
# Connector6               0.0000                0.0000
# Station                  0.1952                8.0640
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.7002
# Connector2  0.0379  0.0121   0.0042   0.0216  1.047711e+08   3.7381
# Storage     0.2172  0.1773   0.0399   0.0000  2.014800e+09   3.9553
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.9553
# Connector4  0.8970  0.3051   0.1198   0.4721  3.024206e+09   4.8523
# Transport   0.4572  0.2553   0.1604   0.0414  1.851800e+09   5.3095
# Connector5  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.3095
# Connector6  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.3095
# Station     1.3601  0.8478   0.2844   0.2278  5.742801e+09   6.6695
#
#               technology    nTrucks  pipeLength    Loss  electricityRES  \
# Production  Electrolyzer     0.0000           0  0.0000         47.6000
# Connector1          None     0.0000           0  1.0000          0.0000
# Connector2    Compressor     0.0000           0  1.0015          0.2675
# Storage       GH2-Cavern     0.0000           0  1.0000          0.0000
# Connector3          None     0.0000           0  1.0000          0.0000
# Connector4  Liquefaction     0.0000           0  1.0165          0.0000
# Transport      LH2-Truck  1815.4898           0  1.0000          0.0000
# Connector5          None     0.0000           0  1.0000          0.0000
# Connector6          None     0.0000           0  1.0000          0.0000
# Station              LH2     0.0000           0  1.0300          0.0000
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production             0.00         0.0  0.0000        1.0486
# Connector1             0.00         0.0  0.0000        1.0486
# Connector2             0.00         0.0  0.0000        1.0470
# Storage                0.00         0.0  0.0000        1.0470
# Connector3             0.00         0.0  0.0000        1.0470
# Connector4             6.78         0.0  0.0000        1.0300
# Transport              0.00         0.0  0.1768        1.0300
# Connector5             0.00         0.0  0.0000        1.0300
# Connector6             0.00         0.0  0.0000        1.0300
# Station                0.60         0.0  0.0000        1.0000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              179.6822
# Connector1               0.0000                0.0000
# Connector2               0.0000                1.0082
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.8520               35.1963
# Transport                0.0579                0.7867
# Connector5               0.0000                0.0000
# Connector6               0.0000                0.0000
# Station                  0.0732                3.0240
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.7002
# Connector2  0.0379  0.0121   0.0042   0.0216  1.047711e+08   3.7381
# Storage     0.2172  0.1773   0.0399   0.0000  2.014800e+09   3.9553
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.9553
# Connector4  0.1092  0.0356   0.0105   0.0631  3.528460e+08   4.0645
# Transport   0.6369  0.1837   0.3432   0.1100  1.204094e+09   4.7014
# Connector5  0.0000  0.0000   0.0000   0.0000  0.000000e+00   4.7014
# Connector6  0.0000  0.0000   0.0000   0.0000  0.000000e+00   4.7014
# Station     2.9035  1.4474   0.4856   0.9705  9.804583e+09   7.6049
#
#                technology    nTrucks  pipeLength    Loss  electricityRES  \
# Production   Electrolyzer     0.0000           0  0.0000         47.6000
# Connector1           None     0.0000           0  1.0000          0.0000
# Connector2     Compressor     0.0000           0  1.0015          0.2675
# Storage        GH2-Cavern     0.0000           0  1.0000          0.0000
# Connector3           None     0.0000           0  1.0000          0.0000
# Connector4  Hydrogenation     0.0000           0  1.0100          0.0000
# Transport      LOHC-Truck  3884.1734           0  1.0000          0.0000
# Connector5           None     0.0000           0  1.0000          0.0000
# Connector6           None     0.0000           0  1.0000          0.0000
# Station         LOHC (NG)     0.0000           0  1.0050          0.0000
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production             0.00         0.0  0.0000        1.0166
# Connector1             0.00         0.0  0.0000        1.0166
# Connector2             0.00         0.0  0.0000        1.0150
# Storage                0.00         0.0  0.0000        1.0150
# Connector3             0.00         0.0  0.0000        1.0150
# Connector4             0.37         0.0  0.0000        1.0050
# Transport              0.00         0.0  0.4693        1.0050
# Connector5             0.00         0.0  0.0000        1.0050
# Connector6             0.00         0.0  0.0000        1.0050
# Station                4.40        11.7  0.0000        1.0000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              174.1999
# Connector1               0.0000                0.0000
# Connector2               0.0000                0.9775
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.0454                1.8741
# Transport                0.1500                2.0376
# Connector5               0.0000                0.0000
# Connector6               0.0000                0.0000
# Station                  3.3214               68.5080
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  1.0599  0.4251   0.1670   0.4679  4.213490e+09   4.7601
# Connector2  0.0000  0.0000   0.0000   0.0000  0.000000e+00   4.7601
# Storage     0.5864  0.4186   0.0822   0.0857  4.148617e+09   5.3466
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.3466
# Connector4  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.3466
# Transport   0.4572  0.2553   0.1604   0.0414  1.851800e+09   5.8037
# Connector5  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.8037
# Connector6  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.8037
# Station     1.3749  0.8478   0.2844   0.2427  5.742801e+09   7.1786
#
#               technology    nTrucks  pipeLength    Loss  electricityRES  \
# Production  Electrolyzer     0.0000           0  0.0000           47.60
# Connector1  Liquefaction     0.0000           0  1.0165            6.78
# Connector2          None     0.0000           0  1.0000            0.00
# Storage         LH2-Tank     0.0000           0  1.0054            0.00
# Connector3          None     0.0000           0  1.0000            0.00
# Connector4          None     0.0000           0  1.0000            0.00
# Transport      LH2-Truck  1815.4898           0  1.0000            0.00
# Connector5          None     0.0000           0  1.0000            0.00
# Connector6          None     0.0000           0  1.0000            0.00
# Station              LH2     0.0000           0  1.0300            0.00
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production              0.0         0.0  0.0000        1.0526
# Connector1              0.0         0.0  0.0000        1.0356
# Connector2              0.0         0.0  0.0000        1.0356
# Storage                 0.0         0.0  0.0000        1.0300
# Connector3              0.0         0.0  0.0000        1.0300
# Connector4              0.0         0.0  0.0000        1.0300
# Transport               0.0         0.0  0.1768        1.0300
# Connector5              0.0         0.0  0.0000        1.0300
# Connector6              0.0         0.0  0.0000        1.0300
# Station                 0.6         0.0  0.0000        1.0000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              180.3819
# Connector1               0.0000               25.2760
# Connector2               0.0000                0.0000
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.0000                0.0000
# Transport                0.0579                0.7867
# Connector5               0.0000                0.0000
# Connector6               0.0000                0.0000
# Station                  0.0732                3.0240
#              TOTEX   CAPEX  fixOPEX  varOPEX        invest  cumCost  \
# Production  3.7002  0.6695   0.1348   2.8960  4.534736e+09   3.7002
# Connector1  0.1215  0.0481   0.0142   0.0592  4.770041e+08   3.8217
# Connector2  0.0000  0.0000   0.0000   0.0000  0.000000e+00   3.8217
# Storage     1.0015  0.8371   0.1644   0.0000  8.297234e+09   4.8232
# Connector3  0.0000  0.0000   0.0000   0.0000  0.000000e+00   4.8232
# Connector4  0.0000  0.0000   0.0000   0.0000  0.000000e+00   4.8232
# Transport   0.6369  0.1837   0.3432   0.1100  1.204094e+09   5.4602
# Connector5  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.4602
# Connector6  0.0000  0.0000   0.0000   0.0000  0.000000e+00   5.4602
# Station     2.9073  1.4474   0.4856   0.9743  9.804583e+09   8.3675
#
#                technology    nTrucks  pipeLength   Loss  electricityRES  \
# Production   Electrolyzer     0.0000           0  0.000           47.60
# Connector1  Hydrogenation     0.0000           0  1.010            0.37
# Connector2           None     0.0000           0  1.000            0.00
# Storage         LOHC-Tank     0.0000           0  1.000            0.00
# Connector3           None     0.0000           0  1.000            0.00
# Connector4           None     0.0000           0  1.000            0.00
# Transport      LOHC-Truck  3884.1734           0  1.000            0.00
# Connector5           None     0.0000           0  1.000            0.00
# Connector6           None     0.0000           0  1.000            0.00
# Station         LOHC (NG)     0.0000           0  1.005            0.00
#
#             electricityGrid  NaturalGas  Diesel  overCapacity  \
# Production              0.0         0.0  0.0000         1.015
# Connector1              0.0         0.0  0.0000         1.005
# Connector2              0.0         0.0  0.0000         1.005
# Storage                 0.0         0.0  0.0000         1.005
# Connector3              0.0         0.0  0.0000         1.005
# Connector4              0.0         0.0  0.0000         1.005
# Transport               0.0         0.0  0.4693         1.005
# Connector5              0.0         0.0  0.0000         1.005
# Connector6              0.0         0.0  0.0000         1.005
# Station                 4.4        11.7  0.0000         1.000
#
#             CO2Emissions[kg/kg]  primaryEnergy[MJ/kg]
# Production               0.0000              173.9390
# Connector1               0.0000                1.3387
# Connector2               0.0000                0.0000
# Storage                  0.0000                0.0000
# Connector3               0.0000                0.0000
# Connector4               0.0000                0.0000
# Transport                0.1500                2.0376
# Connector5               0.0000                0.0000
# Connector6               0.0000                0.0000
# Station                  3.3214               68.5080

# %% [markdown]
# # 7. Creating Plots and Diagrams

# %%
pFun.createPlotsPostProcessing(Results, show=True)

# %% [markdown]
# And finally: A georeferenced plot of the resulting transmission/distribution options

# %%
pipeTransmission=resultsEdgesPipeline.loc[~resultsEdgesPipeline["distribution"]]
pipeDistribution=resultsEdgesPipeline.loc[resultsEdgesPipeline["distribution"]]
pFun.plotGISResultsTriplePlot(area=District,
               pipeT=pipeTransmission.copy(),
               pipeD=pipeDistribution.copy(),
               truckT=resultsEdgesTruck.copy(),
               truckD=resultsEdgesTruck2.copy(),
               hub=Cluster,
               source=Source,
               fuel=FuelingNew,
               colorList=colorList)
plt.show()
