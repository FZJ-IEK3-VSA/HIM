# %% [markdown]
# # Hydrogen Infrastructure Modeling  (for H2 Mobility Study)

# %% [markdown]
# ## Frame assumptions (Scenario for infrastructure design) and hard coded inputs

# %% [markdown]
# For the study, we considered 3 scenarios: 400, 1000 and 7000 fueling stations for 100,000 , 1 million and 20 million FCEV. In general, the calculation for truck or pipeline transportation is different and therefore is has to be selected before.

# %%
analysisType="pipeline"#truck or pipeline
FS=[400, 1000, 7000]
cars=[1e5, 1e6, 20e6]
scenario=2
specificDemand=0.0065#kg/km
mileage=14000
targetFS=FS[scenario]
targetCars=cars[scenario]
maxDistPrioFS=25#km
priceSMR=2.

# %% [markdown]
# ## Frame assumptions (pathways for techno-economic analysis)

# %%
if analysisType=="pipeline":
    hscPathways=[["Electrolyzer","Compressor", "GH2-Cavern","Compressor","Pipeline","None","Pipeline","PipeStation"]]#,
                 #["Electrolyzer","Compressor", "GH2-Cavern","Compressor","Pipeline","Compressor","GH2-Truck","Gstation"]]
elif analysisType=="truck":
    hscPathways=[["Electrolyzer","Compressor", "GH2-Cavern","Compressor","None","None","GH2-Truck","Gstation"],
                 ["Electrolyzer","Compressor", "GH2-Cavern","Liquefaction","None","None","LH2-Truck","LStation"],
                 ["Electrolyzer","Compressor", "GH2-Cavern","Hydrogenation","None","None","LOHC-Truck","LohcStationNG"]]

# %% [markdown]
# ## Plotting boundaries

# %%
bg_area=(87/255, 133/255, 147/255)
bg_lines=(99/255, 150/255, 167/255)
figsize=(9,11)

# %% [markdown]
# ##  Import relevant modules

# %%
import geopandas as gpd
import os
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import time
import numpy as np
from shapely.geometry import Point, LineString
#import processing as prc
from hyInfraGisSupport import data_handling as sFun
from hyInfraGisSupport import optiSetup as optiFun
from hyInfraGisSupport import hsc_classes as hscFun
from matplotlib import gridspec
tictic=time.time()

try:
    from shapely import speedups
    speedups.enable()
except:
    print("speedups not available")

# %% [markdown]
# ## Import Georeference Data

# %% [markdown]
# ### Where to get everything? --> Paths for input data

# %%
tic=time.time()
crs={'ellps': 'GRS80', 'no_defs': True, 'proj': 'utm', 'units': 'm', 'zone': 32}


#%%
path=os.getcwd() + "\\dataH2Mobility\\"
pathFS = path + "101201_Tankstellen_Einteilung_LK_Koords\\101201_Tankstellen_Einteilung_v2_koords_kompakt.shp"
pathCent = path + "Counties.xlsx"
#pathCentCoords = path + "Counties.xlsx"

pathFSdata= path + "101201Tankstellen_v2.csv"
pathSource = path + "H2MobilitySources.xlsx"
pathDemand = path + "H2Demand.csv"
pathDist= path + "Landkreise_vg250_ETRS89_UTM32N.shp"
pathConversion=path+"UmrechnungFabianMartin.xlsx"
#%%
# Read Parameter from Excel File
dfTable = pd.read_excel(path + "ImportTablesTechnologies.xlsx", sheetname=None)
stationScenario="Station"+str(scenario)+"_lr6"
dfTable["Station"]=dfTable[stationScenario]
fabDM=True
District = sFun.import_shp(pathDist, crs=crs, name= "D")
if analysisType=="pipeline":
    pathGasP = path + "\\Netze\\110107_Koords_Punkte_auf_Gasnetz_1km\\110107_Koords_Punkte_auf_Gasnetz_1km.shp"
    NGGridPoint = sFun.import_shp(pathGasP, crs=crs, name="G")

toc=time.time()
print(str(toc-tic)+" Seconds")
# Out:
# 3.9057910442352295 Seconds

# %% [markdown]
# ### Import and manipulate Source, Centroid and other stuff (a lot of single manipulation needed due to different data formats as input!)

# %%
tic=time.time()
#%%
Source=pd.read_excel(pathSource, sheetname=scenario)
Source=gpd.GeoDataFrame(Source)
Source.geometry=[Point((Source.loc[ix,"LON"], Source.loc[ix, "LAT"]))for ix in Source.index]
Source.crs={'init' :'epsg:4326'}
Source=Source.to_crs({'init' :'epsg:7416'})
Source["intIndex"]=Source.index
Source.index=["S"+str(id1) for id1 in Source["intIndex"].values]
Source["ID"]=Source.index
#%%
Centroid=pd.read_excel(pathCent)
Centroid=gpd.GeoDataFrame(Centroid)
Centroid.geometry=[Point((Centroid.loc[ix,"lkXKoor"], Centroid.loc[ix, "lkYKoor"]))for ix in Centroid.index]
Centroid.crs={'init' :'epsg:7416'}
Centroid.index=Centroid["lkSchluessel"].values
Centroid["ID_KRS_BKG"]=Centroid["lkSchluessel"].values
#%%
ConvFabMart=pd.read_excel(pathConversion)
ConvFabMart.index=[int(val) for val in ConvFabMart["old"]]
ConvFabMart["newID"]=[int(val) for val in ConvFabMart["new"]]
#%%
Fueling = sFun.import_shp(pathFS, crs=crs, name="F")
FuelingData = pd.read_csv(pathFSdata, delimiter="@")
FuelingData.index=Fueling.index
#%% Copy Fueling Data to Fueling GeoDataFrame
Fueling=Fueling.join(FuelingData, rsuffix="-")
#%%
#penetration=targetCars/sum(Centroid["lkPKWBenzin"]+Centroid["lkPKWDiesel"])
#Centroid["H2Demand_kt"]=(Centroid["lkPKWBenzin"]+Centroid["lkPKWDiesel"])*penetration*mileage*specificDemand*1e-6
Centroid["H2Demand_kt"]=(Centroid[scenario])*mileage*specificDemand*1e-6
Centroid["intIndex"]=list(range(len(Centroid.index)))
Centroid["INDEX"]=Centroid["intIndex"].values
Centroid.index=["C"+str(id1) for id1 in Centroid["intIndex"].values]
Centroid["ID"]=Centroid.index
#%% H2 Demand
totalH2Demand=sum(Centroid["H2Demand_kt"])
print("Total hydrogen demand: "+ str(totalH2Demand))
#%% Distribution Grid
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# Total hydrogen demand: 1820.0
# 3.55411696434021 Seconds

# %% [markdown]
# ## Importing fueling stations

# %% [markdown]
# ### Import of fueling data + demand calculation

# %%
tic=time.time()
ConvFabMart=pd.read_excel(pathConversion)
ConvFabMart.index=[int(val) for val in ConvFabMart["old"]]
ConvFabMart["newID"]=[int(val) for val in ConvFabMart["new"]]
Fueling = sFun.import_shp(pathFS, crs=crs, name="F")
FuelingData = pd.read_csv(pathFSdata, delimiter="@")
FuelingData.index=Fueling.index
#%% Copy Fueling Data to Fueling GeoDataFrame
Fueling=Fueling.join(FuelingData, rsuffix="-")
toc=time.time()
print(str(toc-tic)+" Seconds 2\n")
#%% Fine
Fueling.loc[Fueling["ABST_2BAHN"]<=maxDistPrioFS,"BAB"] = 1
Fueling["ID_KRS_BKG"]=ConvFabMart.loc[Fueling["ID_KRS_BKG"]]["new"].values
Centroid.index=Centroid["ID_KRS_BKG"]
Fueling["ID_C"]=Centroid.ix[Fueling["ID_KRS_BKG"]]["ID"].values
Centroid.index=Centroid["ID"]
#%% Add the distance to the Centroid in km
Fueling["CentC"]=Centroid.ix[Fueling["ID_C"]].geometry.values
Fueling["CoordsFtoC"]=list(zip(Fueling.geometry, Fueling["CentC"]))
Fueling["EdgesFtoC"]=[LineString(ix) for ix in Fueling["CoordsFtoC"]]
EdgesFtoC=gpd.GeoDataFrame(Fueling["EdgesFtoC"].values, columns=["geometry"], index=Fueling.index)
Fueling["distToC"]=EdgesFtoC.length/1000
#%%
Source["H2ProdCap_kt"]=Source["ProdMax_t"]/1000
Source.loc[Source["H2ProdCap_kt"]>totalH2Demand, "H2ProdCap_kt"]=totalH2Demand
# Out:
# 3.0015170574188232 Seconds 2

# %% [markdown]
# ## Calculate minimum numbers of fueling stations

# %% [markdown]
# Minimum number of fueling stations calculated by demand

# %%
tic=time.time()
fuelingMax_kg_d=totalH2Demand*1e6/365/targetFS#kg/day
fuelingMax_kt_a=fuelingMax_kg_d/1e6*365
#Centroid["minFS"]=[round(Centroid["H2Demand_kt"][ix]/fuelingMax_kt_a+0.5) for ix in Centroid.index]
Centroid["minFS"]=[round(Centroid["H2Demand_kt"][ix]/fuelingMax_kt_a) for ix in Centroid.index]
Centroid["realFS"]=[len(Fueling[Fueling["ID_C"]==ix]) for ix in Centroid.index]
Centroid["highwayFS"]=[sum(Fueling[Fueling["ID_C"]==ix]["BAB"]) for ix in Centroid.index]
#%%
lowFS=Centroid[Centroid["minFS"]>Centroid["realFS"]].index
Centroid.loc[lowFS,"minFS"] = Centroid["realFS"][lowFS].values
#%%
Centroid["H2Demand_kt_F"]= Centroid["H2Demand_kt"]/Centroid["minFS"]
Centroid.loc[Centroid["minFS"]==0,"H2Demand_kt_F"]=0
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# 2.5545389652252197 Seconds

# %% [markdown]
# ## Sorting fueling stations

# %% [markdown]
# Sorting by BAB (Highway fueling stations) --> Area (urban or rural) --> ID (order of appearance)

# %%
tic=time.time()
# ## Sort by highway fueling stations (1st order) and city level (2nd order)
FuelingSorted=Fueling.sort_values(by=["BAB","GEBIET","ID_TS"],ascending=[False,False, True])
print(str(sum(Centroid["minFS"])) + " Tankstellen, davon " + str(sum(Centroid["highwayFS"])) + " Autobahntankstellen")
#%%
### city level weight factors ###
weightFtoF=pd.Series([1., 1.25, 1.25, 1.5, 1.5, 1.5, 1.75, 1.75, 2.],
                     index=["1to1","1to2","2to1","2to2","1to3","3to1","2to3","3to2","3to3"])
# Out:
# 6977.0 Tankstellen, davon 385 Autobahntankstellen

# %% [markdown]
# final fueling stations are not directly the number of target fueling stations --> Rounding of decimals!

# %% [markdown]
# ## Prepare Distance Matrices

# %% [markdown]
# For pipeline: different matrices necessary --> potential network + weight factor!

# %%
tic=time.time()
#Nearest Neighbours
kNN=10
#Prepare coordinates
if analysisType=="pipeline":
    Coords=Centroid.geometry.append(Source.geometry).append(NGGridPoint.geometry).append(Fueling.geometry)
elif analysisType=="truck":
    Coords=Source.geometry.append(Fueling.geometry)
CoordsTotal=pd.DataFrame(Coords,index=Coords.index.values)
CoordsTotal["coordinates"]=pd.Series(sFun.point_array(Coords), index=Coords.index)
#%%
# Calculation distance Matrices
if analysisType=="pipeline":
    # Weight factors
    weightStoG=1.5
    weightCtoC=2.
    weightStoC=2.
    weightCtoG=1.5
    weightGtoG=1.
    #distance Matrices
    distCtoC=sFun.selfDistMatrix(Centroid, weight=weightCtoC, kNN=20)
    distGtoG=sFun.selfDistMatrix(NGGridPoint, weight=weightGtoG, kNN=10)
    distCtoG=sFun.distMatrix(Centroid, NGGridPoint, weight=weightCtoG, kNN=20)
    distStoG=sFun.distMatrix(Source, NGGridPoint, weight=weightStoG, kNN=20)
    distStoC=sFun.distMatrix(Source, Centroid, weight=weightStoC, kNN=20)
    distStoS=sFun.selfDistMatrix(Source, weight=weightStoC, kNN=kNN)
    distFtoF=gpd.GeoDataFrame(columns=distCtoC.columns)
    distTotal=distCtoC.append(distGtoG).append(distCtoG).append(distStoG).append(distStoC).append(distStoS)
toc=time.time()
print(str(toc-tic)+" Seconds\n")
#%%
# Out:
# 44.85961699485779 Seconds

# %% [markdown]
# ## Selecting fueling stations

# %% [markdown]
# The actual selection of fueling stations is working like such: It's searching for each centroid (county) for its minimum number of fueling stations and adds this number of fueling stations. Within this calculation, the algorithm directly creates the distance matrix between the fueling stations inside a county. (open for functionality imporovements)

# %%
FuelingNew=gpd.GeoDataFrame(columns=Fueling.columns)
tic=time.time()
listInID=[]
listTarID=[]
listDistance=[]
listFull=[]

FuelingSorted["coords"]=sFun.point_array(FuelingSorted)
for ix in Centroid.index:
    if Centroid["minFS"][ix]==0:
        continue
    listF=list(FuelingSorted[FuelingSorted["ID_C"]==ix].head(int(Centroid["minFS"][ix]))["ID"])
    listCoords=list(FuelingSorted[FuelingSorted["ID_C"]==ix].head(int(Centroid["minFS"][ix]))["coords"])
    listFull.extend(listF)
#    FuelingNew=FuelingNew.append(dfNew)
    if analysisType=="pipeline":
    #        Distance Matrix inside a Centroid for getting the Minimum Spanning Tree
    #        distFtoFperC=sFun.selfDistMatrixFueling(dfNew, weightFtoF)
        (inID, outID, distance) = sFun.selfDistMatrixFueling(listF, listCoords)
        listInID.extend(inID)
        listTarID.extend(outID)
        listDistance.extend(distance)
FuelingNew=Fueling.ix[listFull]
if analysisType=="pipeline":
    distFtoF=pd.DataFrame([listInID,
                           listTarID,
                           listDistance],
                          index=["inputID",
                                 "targetID",                              
                                 "distance"]).T
    distFtoF=distFtoF[distFtoF.inputID != distFtoF.targetID]
    distFtoF["inputArea"]=FuelingNew.loc[distFtoF["inputID"].values,"GEBIET"].values
    distFtoF["targetArea"]=FuelingNew.loc[distFtoF["targetID"].values,"GEBIET"].values
    distFtoF["weightID"]=[str(distFtoF["inputArea"][ix])+"to"+str(distFtoF["targetArea"][ix]) for ix in distFtoF.index]
    distFtoF["weightedDistance"]=weightFtoF[distFtoF["weightID"]].values*distFtoF["distance"]
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# 21.091522932052612 Seconds

# %% [markdown]
# ## Manipulating the new stations and the final informations for the network approach

# %%
tic=time.time()

FuelingNew["intIndex"]=FuelingNew["intIndex"].values.astype(int)
FuelingNew.intIndex=[x for x, item in enumerate(FuelingNew.index)]
weightStreetSimple=1.3
if analysisType=="truck":
    distFtoS=sFun.distMatrix(FuelingNew, Source, weight=weightStreetSimple, kNN=len(Source.geometry))
    distTotal=distFtoS
#elif analysisType=="pipeline":
#    distTotal=distTotal.append(distFtoF)
#%%
FuelingNew["areaID"]=[str(int(FuelingNew["GEBIET"][ix]))+"to1" for ix in FuelingNew.index]
FuelingNew["weightedLength"]=[weightFtoF[FuelingNew["areaID"][ix]]*FuelingNew["distToC"][ix] for ix in FuelingNew.index]
FuelingNew["H2Demand_kt_F"]=[Centroid.loc[ID_C, "H2Demand_kt_F"] for ID_C in FuelingNew["ID_C"]]
FuelingNew["H2Demand_kg_d_F"]=FuelingNew["H2Demand_kt_F"]*1e6/365
   
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# 3.851832151412964 Seconds

# %% [markdown]
# ## preparing NetworkX for distribution

# %% [markdown]
# Initializing the graph and adding nodes/edges with empty capacity, maximum production, real production and real demand. Afterwards, we apply the maximum capacity and the demand of the fueling stations to the nodes.

# %%
distTotal
# Out:
#            inputID targetID distance weightedDistance
# (C0, C11)       C0      C11  18.6152          37.2304
# (C0, C6)        C0       C6  40.3257          80.6514
# (C0, C10)       C0      C10  59.1039          118.208
# (C0, C1)        C0       C1  68.0024          136.005
# (C0, C4)        C0       C4  75.8353          151.671
# (C0, C9)        C0       C9  84.9592          169.918
# (C0, C3)        C0       C3   85.986          171.972
# (C0, C13)       C0      C13  95.9315          191.863
# (C0, C12)       C0      C12  106.477          212.954
# (C0, C7)        C0       C7  111.242          222.485
# (C0, C8)        C0       C8  120.688          241.376
# (C0, C2)        C0       C2  131.763          263.526
# (C0, C14)       C0      C14  131.866          263.731
# (C0, C42)       C0      C42  132.714          265.427
# (C0, C35)       C0      C35  136.456          272.912
# (C0, C15)       C0      C15  142.687          285.374
# (C0, C63)       C0      C63  148.474          296.947
# (C0, C5)        C0       C5  153.212          306.425
# (C0, C349)      C0     C349  159.362          318.723
# (C0, C49)       C0      C49      162          323.999
# (C1, C9)        C1       C9  17.6277          35.2554
# (C1, C10)       C1      C10   23.252           46.504
# (C1, C3)        C1       C3  29.0102          58.0203
# (C1, C12)       C1      C12  45.0598          90.1195
# (C1, C7)        C1       C7   47.235            94.47
# (C1, C11)       C1      C11  52.2355          104.471
# (C1, C13)       C1      C13  60.2394          120.479
# (C1, C2)        C1       C2  63.8014          127.603
# (C1, C0)        C1       C0  68.0024          136.005
# (C1, C14)       C1      C14  68.4963          136.993
# ...            ...      ...      ...              ...
# (S12, S11)     S12      S11  55.4858          110.972
# (S12, S14)     S12      S14  86.8281          173.656
# (S12, S13)     S12      S13   112.32           224.64
# (S12, S9)      S12       S9  127.887          255.773
# (S12, S10)     S12      S10  138.939          277.877
# (S12, S8)      S12       S8  144.297          288.593
# (S12, S3)      S12       S3  159.072          318.144
# (S12, S7)      S12       S7  178.565          357.131
# (S12, S5)      S12       S5  178.947          357.894
# (S12, S4)      S12       S4  200.266          400.531
# (S13, S14)     S13      S14  41.2459          82.4917
# (S13, S11)     S13      S11  71.7525          143.505
# (S13, S12)     S13      S12   112.32           224.64
# (S13, S1)      S13       S1   127.94          255.881
# (S13, S8)      S13       S8  132.179          264.358
# (S13, S9)      S13       S9  141.295           282.59
# (S13, S10)     S13      S10  165.096          330.193
# (S13, S4)      S13       S4  186.407          372.814
# (S13, S3)      S13       S3  189.081          378.162
# (S13, S7)      S13       S7  191.923          383.845
# (S14, S11)     S14      S11  35.2314          70.4627
# (S14, S13)     S14      S13  41.2459          82.4917
# (S14, S12)     S14      S12  86.8281          173.656
# (S14, S8)      S14       S8  98.0839          196.168
# (S14, S9)      S14       S9  102.356          204.712
# (S14, S10)     S14      S10  125.323          250.647
# (S14, S3)      S14       S3  149.422          298.844
# (S14, S7)      S14       S7  154.787          309.575
# (S14, S4)      S14       S4  155.479          310.958
# (S14, S5)      S14       S5  166.754          333.508
#
# [116850 rows x 4 columns]

# %%
tic=time.time()
# ## Import to NetworkX for minimum spanning tree
G_total=optiFun.PipeNetWork()
G_total.add_weighted_edges_from(list(zip(distTotal["inputID"], distTotal["targetID"], distTotal["weightedDistance"])),
                                capacity=0)
#if analysisType=="pipeline":
#    G_total.add_weighted_edges_from(list(zip(FuelingNew.index, FuelingNew.ID_C, FuelingNew.distToC)),
#                                    capacity=0)



G_total.add_nodes_from(nodes = G_total.nodes(),
                       productionMax = 0,
                       production = 0,
                       demand = 0)

nx.set_node_attributes(G_total, "productionMax", Source.H2ProdCap_kt.to_dict())
nx.set_node_attributes(G_total, "demand", Centroid["H2Demand_kt"].to_dict())

# %%
tic=time.time()
#testLen={source:nx.shortest_path_length(G_total, weight='weight', source=source) for source in Source.index}
#testPath={source:nx.shortest_path(G_total, weight='weight', source=source) for source in Source.index}


testPath2={source:{target:testPath[source][target] for target in Centroid.index} for source in Source.index}

testNodes={}
for source in testPath2:
    for target in testPath2[source]:
        for coord in testPath2[source][target]:
            try: testNodes[coord]=testNodes[coord]+1
            except:
                testNodes[coord]=1
                
listNodes=[x[0] for x in testNodes.items()]
difference=[]
for x in G_total.nodes():
    if x not in listNodes:
        difference.append(x)
G_total.remove_nodes_from(difference)

G_new=optiFun.PipeNetWork()
for source in testPath2:
    print(source)
    for target in testPath2[source]:
        G_new.add_path(testPath2[source][target])

        
        
G_total.remove_edges_from(nx.difference(G_total, G_new).edges())

G_total.reduceNetworkSize()

#G_total.add_weighted_edges_from(list(zip(distFtoF["inputID"], distFtoF["targetID"], distFtoF["weightedDistance"])),
#                                capacity=0)

    
toc=time.time()
print(toc-tic)
# Out:
# S9
# S12
# S3
# S2
# S4
# S1
# S14
# S6
# S10
# S13
# S7
# S0
# S11
# S8
# S5
# Number of nodes before Reduction: 5189
# Number of nodes after Reduction: 2501
# Number of nodes after Reduction: 2309
# Number of nodes after Reduction: 2294
# Number of nodes after Reduction: 2294
# 6.414520025253296

# %%
#if analysisType=="pipeline":
    #G_total.useMinSpanTree(weight="weight")
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# 69.38398218154907 Seconds

# %%
G_total.minSpanTree=True

# %%
G_total.number_of_edges()
# Out:
# 3958

# %% [markdown]
# ## Initialize Optimization Problem

# %%
tic=time.time()
if analysisType=="pipeline":
    G_total.initOpti()
elif analysisType=="truck":
    G_total.initOptiTruck()
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# 1.8087308406829834 Seconds

# %% [markdown]
# ## Solve Optimization

# %%
tic=time.time()
G_total.optModel()
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# Changed value of parameter MIPGap to 0.001
#    Prev: 0.0001  Min: 0.0  Max: 1e+100  Default: 0.0001
# Changed value of parameter TimeLimit to 2000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter logfile to Optimization.log
#    Prev: gurobi.log  Default:
# Changed value of parameter Threads to 7
#    Prev: 0  Min: 0  Max: 1024  Default: 0
# Parameter LogToConsole unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Optimize a model with 16463 rows, 18127 columns and 48127 nonzeros
# Variable types: 14169 continuous, 3958 integer (3958 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [3e-02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-01, 5e+02]
# Presolve removed 3043 rows and 3028 columns
# Presolve time: 0.08s
# Presolved: 13420 rows, 15099 columns, 41496 nonzeros
# Variable types: 11328 continuous, 3771 integer (3771 binary)
#
# Root relaxation: objective 3.667067e+08, 15388 iterations, 1.51 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.6671e+08    0 1343          - 3.6671e+08      -     -    1s
#      0     0 3.7719e+08    0 1471          - 3.7719e+08      -     -    3s
#      0     0 3.7763e+08    0 1490          - 3.7763e+08      -     -    4s
#      0     0 3.9429e+08    0 1484          - 3.9429e+08      -     -    5s
#      0     0 3.9499e+08    0 1506          - 3.9499e+08      -     -    5s
#      0     0 3.9940e+08    0 1550          - 3.9940e+08      -     -    6s
#      0     0 4.0041e+08    0 1591          - 4.0041e+08      -     -    6s
#      0     0 4.0155e+08    0 1664          - 4.0155e+08      -     -    7s
#      0     0 4.0166e+08    0 1705          - 4.0166e+08      -     -    7s
#      0     0 4.0229e+08    0 1720          - 4.0229e+08      -     -    8s
#      0     0 4.0236e+08    0 1735          - 4.0236e+08      -     -    8s
#      0     0 4.0276e+08    0 1773          - 4.0276e+08      -     -    9s
# H    0     0                    6.367398e+10 4.0276e+08  99.4%     -    9s
#      0     0 4.0276e+08    0 1642 6.3674e+10 4.0276e+08  99.4%     -    9s
#      0     2 4.0276e+08    0 1586 6.3674e+10 4.0276e+08  99.4%     -   12s
#    172   173 4.0503e+08   25 1591 6.3674e+10 4.0300e+08  99.4%  55.1   15s
#    483   485 4.0938e+08   63 1447 6.3674e+10 4.0300e+08  99.4%  44.0   20s
# H  499   501                    5.538473e+08 4.0300e+08  27.2%  43.4   20s
#    547   548 4.0980e+08   70 1402 5.5385e+08 4.0300e+08  27.2%  42.5   54s
# H  551   552                    4.397434e+08 4.0300e+08  8.36%  42.4   54s
#    651   653 4.1047e+08   84 1373 4.3974e+08 4.0300e+08  8.36%  38.8   55s
#   1444  1412 4.1317e+08  180 1213 4.3974e+08 4.0300e+08  8.36%  27.1   60s
#   2264  2212 4.1427e+08  281 1039 4.3974e+08 4.0300e+08  8.36%  21.3   65s
#   3473  3390 4.1669e+08  391  952 4.3974e+08 4.0300e+08  8.36%  17.7   70s
#   4267  4166 4.2149e+08  468  893 4.3974e+08 4.0300e+08  8.36%  16.7   75s
#   5221  5101 4.2368e+08  598  797 4.3974e+08 4.0300e+08  8.36%  15.2   80s
#   5980  5829 4.2517e+08  688  689 4.3974e+08 4.0300e+08  8.36%  14.7   85s
#   6670  6507 4.2535e+08  774  645 4.3974e+08 4.0300e+08  8.36%  14.3   90s
#   7660  7471 4.2624e+08  900  551 4.3974e+08 4.0300e+08  8.36%  13.6   96s
#   8470  8260 4.2749e+08  999  479 4.3974e+08 4.0300e+08  8.36%  13.0  100s
#   9354  9123 4.2833e+08 1102  428 4.3974e+08 4.0300e+08  8.36%  12.5  105s
#  10294 10039 4.2880e+08 1201  384 4.3974e+08 4.0300e+08  8.36%  12.0  110s
#  11355 11061 4.2968e+08 1315  311 4.3974e+08 4.0300e+08  8.36%  11.5  115s
#  12423 12077 4.3068e+08 1441  217 4.3974e+08 4.0300e+08  8.36%  10.9  121s
# H13738 13286                    4.396399e+08 4.0300e+08  8.33%  10.4  144s
# H13739 12992                    4.357743e+08 4.0300e+08  7.52%  10.4  144s
# H13740 10027                    4.275917e+08 4.0300e+08  5.75%  10.4  144s
#  13745 10038     cutoff 1569      4.2759e+08 4.0302e+08  5.75%  10.4  147s
#  14165 10431 4.0653e+08   36 1590 4.2759e+08 4.0306e+08  5.74%  10.6  151s
#  15156 11363 4.1539e+08  179 1236 4.2759e+08 4.0306e+08  5.74%  11.1  158s
#  15758 11913 4.2710e+08  445 1642 4.2759e+08 4.0306e+08  5.74%  11.2  178s
#  15760 11914 4.2305e+08  591 1314 4.2759e+08 4.0306e+08  5.74%  11.2  183s
#  15761 11915 4.1429e+08  282 1375 4.2759e+08 4.0306e+08  5.74%  11.2  185s
#  15765 11918 4.1750e+08  244 1373 4.2759e+08 4.0944e+08  4.25%  11.2  191s
#  15768 11920 4.2286e+08  568 1542 4.2759e+08 4.1154e+08  3.75%  11.2  196s
#  15771 11922 4.2584e+08  977 1486 4.2759e+08 4.1310e+08  3.39%  11.2  201s
#  15773 11923 4.2112e+08  456 1589 4.2759e+08 4.1355e+08  3.28%  11.2  205s
#  15776 11925 4.1662e+08  378 1626 4.2759e+08 4.1392e+08  3.20%  11.2  210s
#  15778 11926 4.2710e+08  445 1735 4.2759e+08 4.1419e+08  3.14%  11.2  215s
#  15781 11928 4.1448e+08  282 1669 4.2759e+08 4.1448e+08  3.07%  11.2  222s
#  15783 11930 4.2468e+08  790 1712 4.2759e+08 4.1461e+08  3.04%  11.2  226s
#  15785 11931 4.1750e+08  244 1760 4.2759e+08 4.1469e+08  3.02%  11.2  231s
# H15785 11334                    4.249598e+08 4.1469e+08  2.42%  11.2  231s
#  15787 11335 4.1473e+08   81 1786 4.2496e+08 4.1473e+08  2.41%  11.2  235s
# H15788 10768                    4.246728e+08 4.1475e+08  2.34%  11.2  238s
#  15791 10770 4.2467e+08  977 1755 4.2467e+08 4.1480e+08  2.33%  11.2  242s
#  15793 10771 4.2112e+08  456 1760 4.2467e+08 4.1481e+08  2.32%  11.2  245s
#  15797 10774 4.2467e+08  961 1785 4.2467e+08 4.1485e+08  2.31%  11.2  251s
# H15798 10236                    4.246631e+08 4.1486e+08  2.31%  11.2  254s
#  15800 10237 4.2305e+08  591 1830 4.2466e+08 4.1487e+08  2.31%  11.2  255s
#  15803 10239 4.2466e+08  790 1851 4.2466e+08 4.1488e+08  2.30%  11.2  260s
#  15807 10242 4.1489e+08   81 1814 4.2466e+08 4.1489e+08  2.30%  11.2  266s
#  15810 10244 4.1490e+08   59 1863 4.2466e+08 4.1490e+08  2.30%  11.2  270s
#  15813 10246 4.2112e+08  456 1833 4.2466e+08 4.1490e+08  2.30%  11.2  275s
# H15814  9733                    4.234421e+08 4.1491e+08  2.02%  11.2  283s
#  15817  9735 4.2344e+08  961 1859 4.2344e+08 4.1491e+08  2.02%  11.2  286s
#  15820  9737 4.2305e+08  591 1866 4.2344e+08 4.1495e+08  2.01%  11.2  290s
#  15823  9739 4.2344e+08  790 1823 4.2344e+08 4.1496e+08  2.00%  11.2  295s
#  15827  9742 4.1498e+08   81 1806 4.2344e+08 4.1498e+08  2.00%  11.2  301s
#  15830  9744 4.1498e+08   59 1840 4.2344e+08 4.1498e+08  2.00%  11.2  305s
#  15833  9746 4.2112e+08  456 1842 4.2344e+08 4.1499e+08  2.00%  11.2  310s
#  15837  9749 4.2344e+08  961 1849 4.2344e+08 4.1499e+08  2.00%  11.2  316s
#  15841  9751 4.1499e+08  282 1852 4.2344e+08 4.1499e+08  2.00%  11.2  321s
#  15844  9753 4.1499e+08   10 1885 4.2344e+08 4.1499e+08  2.00%  11.2  325s
#  15847  9755 4.1499e+08   81 1854 4.2344e+08 4.1499e+08  2.00%  11.1  331s
#  15852  9760 4.1499e+08   23 1336 4.2344e+08 4.1499e+08  2.00%  16.4  338s
#  15853  9761 4.2112e+08  456 1392 4.2344e+08 4.1499e+08  2.00%  16.4  340s
#  15855  9762 4.2344e+08 1076 1430 4.2344e+08 4.1499e+08  2.00%  16.4  345s
#  15858  9764 4.2344e+08  445 1713 4.2344e+08 4.1501e+08  1.99%  16.4  351s
#  15860  9766 4.2305e+08  591 1713 4.2344e+08 4.1510e+08  1.97%  16.4  355s
#  15862  9767 4.2344e+08  612 1725 4.2344e+08 4.1517e+08  1.95%  16.4  360s
#  15865  9769 4.1750e+08  244 1644 4.2344e+08 4.1527e+08  1.93%  16.4  366s
#  15867  9770 4.1531e+08   81 1687 4.2344e+08 4.1531e+08  1.92%  16.4  370s
#  15871  9773 4.2344e+08  977 1641 4.2344e+08 4.1538e+08  1.90%  16.4  377s
#  15873  9774 4.2112e+08  456 1695 4.2344e+08 4.1540e+08  1.90%  16.4  380s
# H15874  9285                    4.229631e+08 4.1542e+08  1.78%  16.4  384s
#  15876  9286 4.1662e+08  378 1778 4.2296e+08 4.1543e+08  1.78%  16.4  385s
#  15879  9288 4.2296e+08  934 1726 4.2296e+08 4.1546e+08  1.77%  16.4  391s
#  15882  9290 4.2296e+08  612 1756 4.2296e+08 4.1547e+08  1.77%  16.4  395s
#  15885  9292 4.1750e+08  244 1714 4.2296e+08 4.1549e+08  1.77%  16.4  400s
#  15889  9295 4.1795e+08  267 1710 4.2296e+08 4.1552e+08  1.76%  16.3  406s
# H15890  8831                    4.229405e+08 4.1553e+08  1.75%  16.3  409s
#  15892  8832 4.1554e+08   23 1712 4.2294e+08 4.1554e+08  1.75%  16.3  410s
#  15895  8834 4.2294e+08 1076 1696 4.2294e+08 4.1555e+08  1.75%  16.3  415s
#  15899  8837 4.2294e+08  934 1707 4.2294e+08 4.1556e+08  1.75%  16.3  421s
#  15902  8839 4.2294e+08  612 1736 4.2294e+08 4.1556e+08  1.75%  16.3  425s
#  15905  8841 4.1750e+08  244 1708 4.2294e+08 4.1556e+08  1.74%  16.3  434s
#  15906  8841 4.1556e+08  328 1725 4.2294e+08 4.1556e+08  1.74%  16.3  435s
#  15909  8843 4.1795e+08  267 1723 4.2294e+08 4.1556e+08  1.74%  16.3  440s
#  15911  8845 4.2294e+08  977 1715 4.2294e+08 4.1556e+08  1.74%  16.3  462s
#  15913  8846 4.2112e+08  456 1706 4.2294e+08 4.1556e+08  1.74%  16.3  472s
#  15914  8849 4.1564e+08   26 1682 4.2294e+08 4.1556e+08  1.74%  20.2  544s
#  15916  8851 4.1573e+08   27 1709 4.2294e+08 4.1565e+08  1.72%  20.2  545s
#  15946  8872 4.1597e+08   31 1685 4.2294e+08 4.1571e+08  1.71%  20.3  553s
# H15948  8427                    4.229271e+08 4.1571e+08  1.71%  20.3  553s
#  15980  8446 4.1604e+08   33 1676 4.2293e+08 4.1573e+08  1.70%  20.4  555s
#  16018  8471 4.1617e+08   36 1633 4.2293e+08 4.1574e+08  1.70%  20.5  565s
#  16138  8549 4.1627e+08   43 1658 4.2293e+08 4.1574e+08  1.70%  20.8  570s
#  16312  8664 4.1655e+08   56 1585 4.2293e+08 4.1574e+08  1.70%  21.3  575s
#  16490  8773 4.1667e+08   66 1556 4.2293e+08 4.1574e+08  1.70%  21.8  580s
#  16717  8929 4.1721e+08   78 1479 4.2293e+08 4.1574e+08  1.70%  22.5  586s
#  16948  9070 4.1744e+08   92 1468 4.2293e+08 4.1574e+08  1.70%  23.1  592s
#  17049  9138 4.1751e+08   99 1429 4.2293e+08 4.1574e+08  1.70%  23.3  595s
#  17393  9364 4.1784e+08  118 1387 4.2293e+08 4.1574e+08  1.70%  23.9  601s
#  17569  9462 4.1788e+08  127 1386 4.2293e+08 4.1574e+08  1.70%  24.2  605s
#  17864  9637 4.1820e+08  140 1313 4.2293e+08 4.1574e+08  1.70%  24.9  610s
#  18091  9769 4.1842e+08  158 1250 4.2293e+08 4.1574e+08  1.70%  25.4  615s
#  18566 10102 4.1870e+08  193 1169 4.2293e+08 4.1574e+08  1.70%  25.9  622s
#  18754 10167 4.1891e+08  206 1157 4.2293e+08 4.1574e+08  1.70%  26.1  625s
#  19138 10456 4.1941e+08  233 1093 4.2293e+08 4.1574e+08  1.70%  26.3  630s
#  19587 10730 4.1986e+08  266 1007 4.2293e+08 4.1574e+08  1.70%  26.5  636s
#  19784 10820 4.2103e+08  285  929 4.2293e+08 4.1574e+08  1.70%  26.7  640s
#  20251 11097 4.2124e+08  314  910 4.2293e+08 4.1574e+08  1.70%  27.0  647s
#  20530 11283 4.2162e+08  340  904 4.2293e+08 4.1574e+08  1.70%  27.0  650s
#  21065 11554 4.2226e+08  391  895 4.2293e+08 4.1574e+08  1.70%  27.2  686s
#  21074 11545 4.2243e+08  391  898 4.2293e+08 4.1574e+08  1.70%  27.2  690s
#  21588 11803 4.1610e+08   45 1649 4.2293e+08 4.1576e+08  1.69%  27.5  698s
#  21830 11951 4.1663e+08   74 1550 4.2293e+08 4.1576e+08  1.69%  27.7  702s
#  22093 12066 4.1827e+08  104 1414 4.2293e+08 4.1576e+08  1.69%  28.0  706s
#  22323 12211 4.1912e+08  144 1241 4.2293e+08 4.1576e+08  1.69%  28.4  710s
#  22896 12565 4.2090e+08  306  862 4.2293e+08 4.1576e+08  1.69%  28.9  719s
#  23166 12722 4.2152e+08  399  716 4.2293e+08 4.1576e+08  1.69%  29.2  724s
#  23547 12980 4.2228e+08  535  460 4.2293e+08 4.1576e+08  1.69%  29.3  730s
#  23983 13241 4.2289e+08  681  184 4.2293e+08 4.1578e+08  1.69%  29.5  737s
#  24361 13410 4.1617e+08   41 1647 4.2293e+08 4.1578e+08  1.69%  29.7  742s
#  24746 13641 4.1741e+08   81 1525 4.2293e+08 4.1578e+08  1.69%  29.9  748s
#  25080 13834 4.1913e+08  130 1297 4.2293e+08 4.1578e+08  1.69%  30.3  754s
#  25519 14105 4.2068e+08  209 1146 4.2293e+08 4.1578e+08  1.69%  30.6  761s
#  26097 14476 4.2228e+08  303  882 4.2293e+08 4.1579e+08  1.69%  30.7  768s
#  26597 14714 4.1665e+08   46 1585 4.2293e+08 4.1579e+08  1.69%  30.8  775s
#  26751 14822 4.1693e+08   53 1549 4.2293e+08 4.1579e+08  1.69%  30.9  782s
#  27152 14999 4.1884e+08  121 1382 4.2293e+08 4.1579e+08  1.69%  31.2  789s
#  27668 15304 4.2139e+08  220 1092 4.2293e+08 4.1579e+08  1.69%  31.5  797s
#  28276 15675     cutoff  358      4.2293e+08 4.1580e+08  1.68%  31.7  805s
#  28661 15894 4.1665e+08   50 1613 4.2293e+08 4.1580e+08  1.68%  32.0  812s
#  29035 16104 4.1784e+08   93 1454 4.2293e+08 4.1580e+08  1.68%  32.5  817s
# H29054 15664                    4.228947e+08 4.1580e+08  1.68%  32.5  817s
# H29077 15279                    4.228944e+08 4.1580e+08  1.68%  32.6  817s
#  29085 15297 4.1796e+08   98 1417 4.2289e+08 4.1580e+08  1.68%  32.6  825s
#  29590 15593 4.1881e+08  126 1331 4.2289e+08 4.1580e+08  1.68%  33.1  834s
#  30148 15950 4.1950e+08  183 1132 4.2289e+08 4.1580e+08  1.68%  33.4  844s
#  30773 16330 4.2035e+08  219 1123 4.2289e+08 4.1580e+08  1.68%  33.7  854s
#  31553 16784 4.2067e+08  256 1033 4.2289e+08 4.1580e+08  1.68%  33.8  864s
#  32165 17153 4.2115e+08  328  934 4.2289e+08 4.1580e+08  1.68%  34.2  875s
#  32996 17626 4.2146e+08  368  888 4.2289e+08 4.1580e+08  1.68%  34.3  888s
#  33855 18171 4.2207e+08  390  863 4.2289e+08 4.1580e+08  1.68%  34.2  899s
#  34393 18462 4.1592e+08   38 1658 4.2289e+08 4.1580e+08  1.68%  34.2  900s
#  34477 18489 4.2227e+08  420  801 4.2289e+08 4.1583e+08  1.67%  34.4  911s
#  35101 18861 4.1856e+08  186 1642 4.2289e+08 4.1583e+08  1.67%  34.7 1052s
#  35103 18862 4.1659e+08   48 1337 4.2289e+08 4.1583e+08  1.67%  34.7 1057s
#  35104 18863 4.1646e+08   71 1312 4.2289e+08 4.1583e+08  1.67%  34.7 1060s
#  35106 18864 4.2116e+08  230 1252 4.2289e+08 4.1583e+08  1.67%  34.7 1070s
#  35107 18865 4.2275e+08  295 1473 4.2289e+08 4.1583e+08  1.67%  34.7 1075s
#  35108 18866 4.1877e+08  110 1438 4.2289e+08 4.1583e+08  1.67%  34.7 1082s
#  35109 18866 4.2012e+08  139 1516 4.2289e+08 4.1587e+08  1.66%  34.7 1087s
#  35110 18867 4.2137e+08  351 1469 4.2289e+08 4.1595e+08  1.64%  34.7 1094s
#  35111 18868 4.2145e+08  223 1526 4.2289e+08 4.1599e+08  1.63%  34.7 1099s
#  35112 18868 4.1991e+08  236 1540 4.2289e+08 4.1609e+08  1.61%  34.7 1105s
#  35113 18869 4.1958e+08  221 1594 4.2289e+08 4.1611e+08  1.60%  34.7 1110s
#  35114 18870 4.2212e+08  227 1542 4.2289e+08 4.1617e+08  1.59%  34.7 1117s
#  35115 18870 4.2001e+08  195 1607 4.2289e+08 4.1619e+08  1.58%  34.7 1121s
#  35116 18871 4.1662e+08   47 1597 4.2289e+08 4.1625e+08  1.57%  34.7 1129s
#  35117 18872 4.1695e+08   93 1646 4.2289e+08 4.1626e+08  1.57%  34.7 1134s
#  35118 18872 4.1657e+08   58 1541 4.2289e+08 4.1631e+08  1.56%  34.7 1141s
#  35119 18873 4.2226e+08  341 1601 4.2289e+08 4.1634e+08  1.55%  34.7 1146s
#  35120 18874 4.2011e+08  251 1555 4.2289e+08 4.1637e+08  1.54%  34.7 1152s
#  35121 18874 4.1856e+08  186 1601 4.2289e+08 4.1638e+08  1.54%  34.7 1157s
#  35122 18875 4.1942e+08  167 1557 4.2289e+08 4.1643e+08  1.53%  34.7 1164s
#  35123 18876 4.1659e+08   48 1603 4.2289e+08 4.1643e+08  1.53%  34.7 1168s
#  35124 18876 4.1646e+08   71 1574 4.2289e+08 4.1645e+08  1.52%  34.7 1175s
#  35125 18877 4.2166e+08  225 1644 4.2289e+08 4.1646e+08  1.52%  34.7 1180s
#  35126 18878 4.2116e+08  230 1587 4.2289e+08 4.1647e+08  1.52%  34.7 1186s
#  35127 18878 4.2275e+08  295 1623 4.2289e+08 4.1648e+08  1.52%  34.7 1192s
#  35128 18879 4.1877e+08  110 1576 4.2289e+08 4.1649e+08  1.51%  34.7 1200s
#  35130 18880 4.2137e+08  351 1574 4.2289e+08 4.1650e+08  1.51%  34.7 1210s
#  35132 18882 4.1991e+08  236 1557 4.2289e+08 4.1651e+08  1.51%  34.7 1220s
# H35132 17937                    4.228428e+08 4.1651e+08  1.50%  34.7 1220s
#  35134 17938 4.2212e+08  227 1579 4.2284e+08 4.1652e+08  1.49%  34.7 1229s
#  35135 17939 4.2001e+08  195 1632 4.2284e+08 4.1653e+08  1.49%  34.7 1233s
# H35135 17041                    4.228174e+08 4.1653e+08  1.49%  34.7 1238s
#  35137 17042 4.1695e+08   93 1587 4.2282e+08 4.1655e+08  1.48%  34.7 1242s
#  35138 17043 4.1657e+08   58 1591 4.2282e+08 4.1655e+08  1.48%  34.7 1248s
#  35139 17043 4.2226e+08  341 1598 4.2282e+08 4.1655e+08  1.48%  34.7 1252s
#  35140 17044 4.2011e+08  251 1594 4.2282e+08 4.1656e+08  1.48%  34.7 1257s
#  35141 17045 4.1856e+08  186 1597 4.2282e+08 4.1656e+08  1.48%  34.7 1261s
#  35142 17045 4.1942e+08  167 1573 4.2282e+08 4.1656e+08  1.48%  34.7 1266s
#  35143 17046 4.1659e+08   48 1603 4.2282e+08 4.1656e+08  1.48%  34.7 1271s
#  35144 17047 4.1656e+08   71 1585 4.2282e+08 4.1656e+08  1.48%  34.7 1276s
#  35145 17047 4.2166e+08  225 1595 4.2282e+08 4.1656e+08  1.48%  34.7 1280s
#  35146 17048 4.2116e+08  230 1559 4.2282e+08 4.1656e+08  1.48%  34.7 1285s
#  35148 17049 4.1877e+08  110 1572 4.2282e+08 4.1657e+08  1.48%  34.7 1294s
#  35149 17050 4.2012e+08  139 1604 4.2282e+08 4.1657e+08  1.48%  34.7 1298s
#  35150 17051 4.2137e+08  351 1580 4.2282e+08 4.1657e+08  1.48%  34.7 1304s
#  35151 17051 4.2145e+08  223 1594 4.2282e+08 4.1657e+08  1.48%  34.7 1308s
#  35152 17052 4.1991e+08  236 1582 4.2282e+08 4.1658e+08  1.48%  34.7 1314s
#  35153 17053 4.1958e+08  221 1605 4.2282e+08 4.1658e+08  1.48%  34.7 1318s
#  35154 17053 4.2212e+08  227 1596 4.2282e+08 4.1658e+08  1.48%  34.7 1323s
#  35155 17054 4.2001e+08  195 1608 4.2282e+08 4.1658e+08  1.48%  34.7 1327s
#  35156 17055 4.1662e+08   47 1583 4.2282e+08 4.1658e+08  1.47%  34.7 1333s
#  35157 17055 4.1695e+08   93 1595 4.2282e+08 4.1658e+08  1.47%  34.7 1338s
#  35158 17056 4.1658e+08   58 1583 4.2282e+08 4.1658e+08  1.47%  34.7 1344s
#  35159 17057 4.2226e+08  341 1606 4.2282e+08 4.1658e+08  1.47%  34.7 1349s
# H35159 16204                    4.226005e+08 4.1658e+08  1.42%  34.7 1360s
#  35162 16206 4.1942e+08  167 1594 4.2260e+08 4.1659e+08  1.42%  34.7 1374s
#  35163 16206 4.1659e+08   48 1614 4.2260e+08 4.1659e+08  1.42%  34.7 1378s
#  35164 16207 4.1659e+08   71 1597 4.2260e+08 4.1659e+08  1.42%  34.7 1385s
#  35166 16208 4.2116e+08  230 1562 4.2260e+08 4.1659e+08  1.42%  34.7 1399s
#  35167 16209 4.2260e+08  295 1582 4.2260e+08 4.1659e+08  1.42%  34.7 1403s
# H35167 15397                    4.225794e+08 4.1661e+08  1.41%  34.7 1411s
#  35169 15398 4.2012e+08  139 1589 4.2258e+08 4.1662e+08  1.41%  34.7 1415s
#  35170 15399 4.2137e+08  351 1586 4.2258e+08 4.1662e+08  1.41%  34.7 1424s
#  35171 15400 4.2145e+08  223 1602 4.2258e+08 4.1663e+08  1.41%  34.7 1429s
#  35172 15400 4.1991e+08  236 1595 4.2258e+08 4.1663e+08  1.41%  34.7 1435s
#  35173 15401 4.1958e+08  221 1604 4.2258e+08 4.1663e+08  1.41%  34.7 1440s
#  35174 15402 4.2212e+08  227 1579 4.2258e+08 4.1663e+08  1.41%  34.7 1446s
#  35175 15402 4.2001e+08  195 1594 4.2258e+08 4.1663e+08  1.41%  34.7 1450s
#  35176 15403 4.1663e+08   47 1584 4.2258e+08 4.1663e+08  1.41%  34.7 1456s
#  35177 15404 4.1695e+08   93 1601 4.2258e+08 4.1663e+08  1.41%  34.7 1460s
#  35178 15404 4.1663e+08   58 1561 4.2258e+08 4.1663e+08  1.41%  34.7 1465s
#  35179 15405 4.2226e+08  341 1572 4.2258e+08 4.1663e+08  1.41%  34.7 1470s
#  35180 15406 4.2011e+08  251 1557 4.2258e+08 4.1663e+08  1.41%  34.7 1475s
#  35181 15406 4.1856e+08  186 1572 4.2258e+08 4.1663e+08  1.41%  34.7 1480s
#  35182 15407 4.1942e+08  167 1557 4.2258e+08 4.1663e+08  1.41%  34.7 1488s
#  35183 15408 4.1663e+08   48 1569 4.2258e+08 4.1663e+08  1.41%  34.7 1493s
#  35184 15408 4.1663e+08   71 1550 4.2258e+08 4.1663e+08  1.41%  34.7 1498s
#  35185 15409 4.2166e+08  225 1569 4.2258e+08 4.1663e+08  1.41%  34.7 1503s
#  35186 15410 4.2116e+08  230 1551 4.2258e+08 4.1663e+08  1.41%  34.7 1508s
#  35187 15410 4.2258e+08  295 1576 4.2258e+08 4.1663e+08  1.41%  34.7 1513s
#  35188 15411 4.1877e+08  110 1554 4.2258e+08 4.1663e+08  1.41%  34.7 1519s
#  35189 15412 4.2012e+08  139 1574 4.2258e+08 4.1663e+08  1.41%  34.7 1524s
#  35190 15412 4.2137e+08  351 1569 4.2258e+08 4.1663e+08  1.41%  34.7 1530s
#  35192 15414 4.1991e+08  236 1543 4.2258e+08 4.1663e+08  1.41%  34.7 1539s
#  35193 15414 4.1958e+08  221 1561 4.2258e+08 4.1663e+08  1.41%  34.7 1544s
#  35194 15415 4.2212e+08  227 1567 4.2258e+08 4.1663e+08  1.41%  34.7 1550s
#  35196 15416 4.1663e+08   47 1563 4.2258e+08 4.1663e+08  1.41%  34.7 1559s
#  35197 15417 4.1695e+08   93 1581 4.2258e+08 4.1663e+08  1.41%  34.7 1563s
#  35198 15418 4.1663e+08   58 1561 4.2258e+08 4.1663e+08  1.41%  34.7 1573s
#  35199 15418 4.2226e+08  341 1571 4.2258e+08 4.1663e+08  1.41%  34.7 1576s
#  35200 15419 4.2011e+08  251 1559 4.2258e+08 4.1663e+08  1.41%  34.6 1582s
#  35201 15420 4.1856e+08  186 1584 4.2258e+08 4.1663e+08  1.41%  34.6 1586s
#  35202 15420 4.1942e+08  167 1566 4.2258e+08 4.1663e+08  1.41%  34.6 1593s
#  35203 15421 4.1663e+08   48 1585 4.2258e+08 4.1663e+08  1.41%  34.6 1598s
#  35204 15422 4.1663e+08   71 1557 4.2258e+08 4.1663e+08  1.41%  34.6 1603s
#  35205 15422 4.2166e+08  225 1573 4.2258e+08 4.1663e+08  1.41%  34.6 1607s
#  35206 15423 4.2116e+08  230 1572 4.2258e+08 4.1663e+08  1.41%  34.6 1612s
#  35207 15424 4.2258e+08  295 1586 4.2258e+08 4.1663e+08  1.41%  34.6 1617s
#  35208 15424 4.1877e+08  110 1574 4.2258e+08 4.1663e+08  1.41%  34.6 1623s
#  35209 15425 4.2012e+08  139 1589 4.2258e+08 4.1664e+08  1.41%  34.6 1628s
#  35210 15426 4.2137e+08  351 1578 4.2258e+08 4.1664e+08  1.41%  34.6 1635s
#  35211 15426 4.2145e+08  223 1603 4.2258e+08 4.1664e+08  1.41%  34.6 1640s
#  35212 15427 4.1991e+08  236 1586 4.2258e+08 4.1664e+08  1.41%  34.6 1651s
#  35213 15428 4.1958e+08  221 1601 4.2258e+08 4.1664e+08  1.41%  34.6 1656s
#  35214 15428 4.2212e+08  227 1592 4.2258e+08 4.1664e+08  1.41%  34.6 1662s
#  35215 15429 4.2001e+08  195 1604 4.2258e+08 4.1664e+08  1.41%  34.6 1666s
#  35216 15430 4.1664e+08   47 1580 4.2258e+08 4.1664e+08  1.41%  34.6 1673s
#  35217 15430 4.1695e+08   93 1591 4.2258e+08 4.1664e+08  1.41%  34.6 1677s
#  35218 15431 4.1664e+08   58 1591 4.2258e+08 4.1664e+08  1.41%  34.6 1682s
#  35219 15432 4.2226e+08  341 1593 4.2258e+08 4.1664e+08  1.41%  34.6 1686s
#  35220 15432 4.2011e+08  251 1564 4.2258e+08 4.1664e+08  1.41%  34.6 1692s
#  35221 15433 4.1856e+08  186 1581 4.2258e+08 4.1664e+08  1.41%  34.6 1698s
#  35222 15434 4.1942e+08  167 1581 4.2258e+08 4.1664e+08  1.41%  34.6 1704s
#  35223 15434 4.1664e+08   48 1598 4.2258e+08 4.1664e+08  1.41%  34.6 1709s
#  35224 15435 4.1664e+08   71 1592 4.2258e+08 4.1664e+08  1.41%  34.6 1714s
#  35225 15436 4.2166e+08  225 1598 4.2258e+08 4.1664e+08  1.41%  34.6 1718s
#  35226 15436 4.2116e+08  230 1577 4.2258e+08 4.1664e+08  1.41%  34.6 1724s
#  35227 15437 4.2258e+08  295 1601 4.2258e+08 4.1664e+08  1.41%  34.6 1728s
#  35228 15438 4.1877e+08  110 1555 4.2258e+08 4.1664e+08  1.41%  34.6 1734s
#  35229 15438 4.2012e+08  139 1581 4.2258e+08 4.1664e+08  1.41%  34.6 1739s
#  35230 15439 4.2137e+08  351 1568 4.2258e+08 4.1664e+08  1.40%  34.6 1749s
#  35231 15440 4.2145e+08  223 1587 4.2258e+08 4.1664e+08  1.40%  34.6 1754s
#  35232 15440 4.1991e+08  236 1572 4.2258e+08 4.1665e+08  1.40%  34.6 1761s
#  35233 15441 4.1958e+08  221 1588 4.2258e+08 4.1665e+08  1.40%  34.6 1765s
#  35234 15442 4.2212e+08  227 1567 4.2258e+08 4.1665e+08  1.40%  34.6 1772s
#  35235 15442 4.2001e+08  195 1581 4.2258e+08 4.1665e+08  1.40%  34.6 1777s
#  35236 15443 4.1665e+08   47 1587 4.2258e+08 4.1665e+08  1.40%  34.6 1783s
#  35237 15444 4.1695e+08   93 1600 4.2258e+08 4.1665e+08  1.40%  34.6 1788s
#  35238 15444 4.1665e+08   58 1579 4.2258e+08 4.1665e+08  1.40%  34.6 1794s
#  35239 15445 4.2226e+08  341 1602 4.2258e+08 4.1665e+08  1.40%  34.6 1798s
#  35240 15446 4.2011e+08  251 1588 4.2258e+08 4.1665e+08  1.40%  34.6 1805s
#  35241 15446 4.1856e+08  186 1608 4.2258e+08 4.1665e+08  1.40%  34.6 1810s
#  35242 15447 4.1942e+08  167 1601 4.2258e+08 4.1665e+08  1.40%  34.6 1816s
#  35243 15448 4.1665e+08   48 1607 4.2258e+08 4.1665e+08  1.40%  34.6 1820s
#  35244 15448 4.1665e+08   71 1594 4.2258e+08 4.1665e+08  1.40%  34.6 1830s
#  35246 15450 4.2116e+08  230 1582 4.2258e+08 4.1665e+08  1.40%  34.6 1840s
#  35248 15451 4.1877e+08  110 1587 4.2258e+08 4.1665e+08  1.40%  34.6 1849s
#  35249 15452 4.2012e+08  139 1600 4.2258e+08 4.1665e+08  1.40%  34.6 1854s
#  35250 15452 4.2137e+08  351 1591 4.2258e+08 4.1665e+08  1.40%  34.6 1861s
#  35251 15453 4.2145e+08  223 1610 4.2258e+08 4.1665e+08  1.40%  34.6 1866s
#  35252 15454 4.1991e+08  236 1581 4.2258e+08 4.1665e+08  1.40%  34.6 1872s
#  35253 15454 4.1958e+08  221 1596 4.2258e+08 4.1665e+08  1.40%  34.6 1876s
#  35254 15455 4.2212e+08  227 1579 4.2258e+08 4.1665e+08  1.40%  34.6 1881s
#  35255 15456 4.2001e+08  195 1600 4.2258e+08 4.1665e+08  1.40%  34.6 1885s
#  35256 15456 4.1665e+08   47 1587 4.2258e+08 4.1665e+08  1.40%  34.6 1890s
#  35257 15457 4.1695e+08   93 1595 4.2258e+08 4.1665e+08  1.40%  34.6 1895s
#  35258 15458 4.1665e+08   58 1580 4.2258e+08 4.1665e+08  1.40%  34.6 1906s
#  35260 15459 4.2011e+08  251 1593 4.2258e+08 4.1666e+08  1.40%  34.6 1915s
#  35262 15460 4.1942e+08  167 1594 4.2258e+08 4.1666e+08  1.40%  34.6 1924s
#  35263 15461 4.1666e+08   48 1600 4.2258e+08 4.1666e+08  1.40%  34.6 1929s
#  35264 15462 4.1666e+08   71 1600 4.2258e+08 4.1666e+08  1.40%  34.6 1935s
#  35266 15463 4.2116e+08  230 1599 4.2258e+08 4.1667e+08  1.40%  34.6 1944s
#  35267 15464 4.2258e+08  295 1618 4.2258e+08 4.1668e+08  1.40%  34.6 1949s
#  35268 15464 4.1877e+08  110 1608 4.2258e+08 4.1668e+08  1.40%  34.6 1956s
#  35269 15465 4.2012e+08  139 1622 4.2258e+08 4.1668e+08  1.40%  34.6 1961s
#  35270 15466 4.2137e+08  351 1610 4.2258e+08 4.1668e+08  1.40%  34.6 1967s
#  35271 15466 4.2145e+08  223 1629 4.2258e+08 4.1668e+08  1.40%  34.6 1973s
#  35272 15467 4.1991e+08  236 1582 4.2258e+08 4.1669e+08  1.39%  34.6 1980s
#  35273 15468 4.1958e+08  221 1631 4.2258e+08 4.1669e+08  1.39%  34.6 1985s
#  35274 15468 4.2212e+08  227 1624 4.2258e+08 4.1669e+08  1.39%  34.6 1995s
#  35275 15469 4.2001e+08  195 1630 4.2258e+08 4.1669e+08  1.39%  34.6 2000s
#
# Cutting planes:
#   Gomory: 310
#   Cover: 60
#   Implied bound: 147
#   Clique: 9
#   MIR: 396
#   Flow cover: 3258
#   Flow path: 84
#   Zero half: 43
#   Network: 40
#
# Explored 35275 nodes (1341111 simplex iterations) in 2000.22 seconds
# Thread count was 7 (of 8 available processors)
#
# Solution count 10: 4.22579e+08 4.22601e+08 4.22817e+08 ... 4.23442e+08
# Pool objective bound 4.1669e+08
#
# Time limit reached
# Best objective 4.225793587786e+08, best bound 4.166900761478e+08, gap 1.3937%
# WARNING - Loading a SolverResults object with an 'aborted' status, but containing a solution
# 2003.478658914566 Seconds

# %% [markdown]
# ## Postprocessing

# %%
tic=time.time()
NodesFinal=G_total.getProductionNodes()
EdgesFinal=G_total.getEdgesAsGpd(CoordsTotal, analysisType)
#%%
Source["H2Production_kt"]=NodesFinal
Source["H2Production_kg_day"]=Source["H2Production_kt"]*1e6/365
toc=time.time()
print(str(toc-tic)+" Seconds\n")
# Out:
# 2.0466389656066895 Seconds

# %% [markdown]
# # techno-economic analysis (Ugly beautiful solved so far!!!)

# %%
for listHSC in hscPathways:
    print("-------------- Preparing total Analysis --------------")
    tic=time.time()
    hscResults=pd.Series()
    hscResultsTot=pd.Series()
    hscResultsInvest=pd.Series()
    hscResultsCAPEX=pd.Series()
    hscResultsOPEX=pd.Series()
    hscResultsEnergy=pd.DataFrame(index=["Loss", "electricityRES", "electricityGrid", "NaturalGas", "Diesel"])
    
    hscName=pd.Series(listHSC,
                      index=["Production","Connector1","Storage","Connector2","Transmission","Connector3","Distribution","Fueling"])
    #%%
    HSC={}
    #%% Production Class
    if scenario==2:
        HSC["Production"]=hscFun.Production(Source["H2Production_kg_day"], hscName["Production"], dfTable)
        Source["productionSpecCost"]=HSC["Production"].getTOTEX()
        Source["productionInvest"]=HSC["Production"].getInvest()
        hscResults["Production"]=np.sum(Source["productionSpecCost"]*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsOPEX["Production"]=np.sum(HSC["Production"].OPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsCAPEX["Production"]=np.sum(HSC["Production"].CAPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsTot["Production"]=hscResults["Production"]
        hscResultsInvest["Production"]=np.sum(Source["productionInvest"])
        hscResultsEnergy["Production"]=HSC["Production"].getDemand()
        #%% Connector Class
        HSC["Con1"]=hscFun.Connector(Source["H2Production_kg_day"], hscName["Connector1"], dfTable, costH2In=Source["productionSpecCost"], pressureIn=30, pressureOut=150)
        Source["con1SpecCost"]=HSC["Con1"].getTOTEX()
        Source["con1Invest"]=HSC["Con1"].getInvest()
        hscResults["Connector1"]=np.sum(Source["con1SpecCost"]*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsOPEX["Connector1"]=np.sum(HSC["Con1"].OPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsCAPEX["Connector1"]=np.sum(HSC["Con1"].CAPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsTot["Connector1"]=hscResultsTot["Production"]+hscResults["Connector1"]
        hscResultsInvest["Connector1"]=np.sum(Source["con1Invest"])
        hscResultsEnergy["Connector1"]=HSC["Con1"].getDemand()
        #%% Storage Class
        HSC["Storage"]=hscFun.Storage(Source["H2Production_kg_day"], hscName["Storage"], dfTable, costH2In=Source["con1SpecCost"])
        Source["storageSpecCost"]=HSC["Storage"].getTOTEX()
        Source["storageInvest"]=HSC["Storage"].getInvest()
        hscResults["Storage"]=np.sum(Source["storageSpecCost"]*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsOPEX["Storage"]=np.sum(HSC["Storage"].OPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsCAPEX["Storage"]=np.sum(HSC["Storage"].CAPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsTot["Storage"]=hscResultsTot["Connector1"]+hscResults["Storage"]
        hscResultsInvest["Storage"]=np.sum(Source["storageInvest"])
        hscResultsEnergy["Storage"]=HSC["Storage"].getDemand()
    else:
        hscResults["Production"]=hscResultsTot["Production"]=priceSMR
        hscResultsOPEX["Production"]=0
        hscResultsOPEX["Production"]=0
        hscResultsCAPEX["Production"]=0
        hscResultsEnergy["Production"]=0
        #%% Connector Class
        hscResultsTot["Connector1"]=priceSMR
        hscResults["Connector1"]=0
        hscResultsOPEX["Connector1"]=0
        hscResultsOPEX["Connector1"]=0
        hscResultsCAPEX["Connector1"]=0
        hscResults["Connector1"]=0
        hscResultsEnergy["Connector1"]=0
        #%% Storage Class
        hscResultsTot["Storage"]=priceSMR
        hscResults["Storage"]=0
        hscResultsOPEX["Storage"]=0
        hscResultsOPEX["Storage"]=0
        hscResultsCAPEX["Storage"]=0
        hscResults["Storage"]=0
        hscResultsEnergy["Storage"]=0
        Source["storageSpecCost"]=hscResultsTot["Storage"]
    #%% Connector 2, Transmission and Distribution Calculation
    if analysisType=="pipeline":
        HSC["Con2"]=hscFun.Connector2(Source["H2Production_kg_day"],
                                      hscName["Connector2"],
                                      dfTable, 
                                      costH2In=Source["storageSpecCost"],
                                      pressureIn=dfTable["Storage"][hscName["Storage"]]["pressureOut"],
                                      pressureOut=dfTable["Transport"][hscName["Transmission"]]["pressureIn"],
                                      nextStep=hscName["Transmission"])
        Source["con2SpecCost"]=HSC["Con2"].getTOTEX()
        Source["con2Invest"]=HSC["Con2"].getInvest()
        hscResults["Connector2"]=np.sum(Source["con2SpecCost"]*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsOPEX["Connector2"]=np.sum(HSC["Con2"].OPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsCAPEX["Connector2"]=np.sum(HSC["Con2"].CAPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsTot["Connector2"]=hscResultsTot["Storage"]+hscResults["Connector2"]  
        hscResultsInvest["Connector2"]=np.sum(Source["con2Invest"])
        hscResultsEnergy["Connector2"]=HSC["Con2"].getDemand()
        
        HSC["Transmission"]=hscFun.Pipeline(totalH2Demand*1e6,
                                                   np.sum(EdgesFinal[EdgesFinal["distribution"]==False]["lineCost"].values*1e6),
                                                   dfTable,
                                                   costH2In=hscResults["Connector2"])
        hscResults["Transmission"]=HSC["Transmission"].getTOTEX()
        hscResultsTot["Transmission"]=hscResultsTot["Connector2"]+hscResults["Transmission"]
        hscResultsCAPEX["Transmission"]=HSC["Transmission"].CAPEX
        hscResultsOPEX["Transmission"]=HSC["Transmission"].OPEX
        hscResultsInvest["Transmission"]=HSC["Transmission"].invest
        hscResultsEnergy["Transmission"]=0
        
        if hscName["Distribution"]=="Pipeline":
            #Connector 3
            hscResults["Connector3"]=0
            hscResultsCAPEX["Connector3"]=0
            hscResultsOPEX["Connector3"]=0
            hscResultsInvest["Connector3"]=0
            hscResultsTot["Connector3"]=hscResultsTot["Transmission"]+hscResults["Connector3"]
            hscResultsEnergy["Connector3"]=0
            #Distribution
            HSC["Distribution"]=hscFun.Pipeline(totalH2Demand*1e6,
                                                       np.sum(EdgesFinal[EdgesFinal["distribution"]]["lineCost"].values*1e6),
                                                       dfTable,
                                                       costH2In=hscResultsTot["Transmission"])
            hscResults["Distribution"]=HSC["Distribution"].getTOTEX()
            hscResultsCAPEX["Distribution"]=HSC["Distribution"].CAPEX
            hscResultsOPEX["Distribution"]=HSC["Distribution"].OPEX
            hscResultsEnergy["Transmission"]=0
        else:
            #Connector 3
            HSC["Con3"]=hscFun.Connector2(Centroid["H2Demand_kt"]*1e6/365,
                                          hscName["Connector3"],
                                          dfTable,
                                          costH2In=hscResultsTot["Transmission"],
                                          pressureIn=dfTable["Transport"][hscName["Transmission"]]["pressureOut"],
                                          pressureOut=dfTable["Transport"][hscName["Distribution"]]["pressureIn"],
                                          nextStep=hscName["Distribution"])
            hscResults["Connector3"]=np.sum(HSC["Con3"].getTOTEX()*Centroid["H2Demand_kt"])/np.sum(Centroid["H2Demand_kt"])
            hscResultsCAPEX["Connector3"]=np.sum(HSC["Con3"].CAPEX*Centroid["H2Demand_kt"])/np.sum(Centroid["H2Demand_kt"])
            hscResultsOPEX["Connector3"]=np.sum(HSC["Con3"].OPEX*Centroid["H2Demand_kt"])/np.sum(Centroid["H2Demand_kt"])
            hscResultsTot["Connector3"]=hscResultsTot["Transmission"]+hscResults["Connector3"]
            hscResultsInvest["Connector3"]=np.sum(HSC["Con3"].invest)
            hscResultsEnergy["Connector3"]=HSC["Con3"].getDemand()
            #Distribution
            HSC["Distribution"]=hscFun.Truck(FuelingNew["H2Demand_kg_d_F"],
                                             FuelingNew["distToC"]*weightStreetSimple,
                                             hscName["Distribution"],
                                             dfTable,
                                             costH2In=hscResults["Connector3"])
            FuelingNew["TOTEX"]=HSC["Distribution"].getTOTEX()
            hscResults["Distribution"]=np.sum(FuelingNew["TOTEX"]*FuelingNew["H2Demand_kg_d_F"])/np.sum(FuelingNew["H2Demand_kg_d_F"])
            hscResultsCAPEX["Distribution"]=np.sum(HSC["Distribution"].CAPEX*FuelingNew["H2Demand_kg_d_F"])/np.sum(FuelingNew["H2Demand_kg_d_F"])
            hscResultsOPEX["Distribution"]=np.sum(HSC["Distribution"].OPEX*FuelingNew["H2Demand_kg_d_F"])/np.sum(FuelingNew["H2Demand_kg_d_F"])
            numberOfTrucks=np.sum(HSC["Distribution"].nTruck)
            hscResultsEnergy["Distribution"]=HSC["Distribution"].getDemand()
    
    elif analysisType=="truck":
        HSC["Con2"]=hscFun.Connector2(Source["H2Production_kg_day"],
                                      hscName["Connector2"],
                                      dfTable,
                                      costH2In=Source["storageSpecCost"],
                                      pressureIn=dfTable["Storage"][hscName["Storage"]]["pressureOut"],
                                      pressureOut=dfTable["Transport"][hscName["Distribution"]]["pressureIn"],
                                      nextStep=hscName["Distribution"])
        Source["con2SpecCost"]=HSC["Con2"].getTOTEX()
        Source["con2Invest"]=HSC["Con2"].getInvest()
        hscResults["Connector2"]=np.sum(Source["con2SpecCost"]*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsOPEX["Connector2"]=np.sum(HSC["Con2"].OPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsCAPEX["Connector2"]=np.sum(HSC["Con2"].CAPEX*Source["H2Production_kg_day"])/np.sum(Source["H2Production_kg_day"])
        hscResultsTot["Connector2"]=hscResultsTot["Storage"]+hscResults["Connector2"]  
        hscResultsInvest["Connector2"]=np.sum(Source["con2Invest"])
        hscResultsEnergy["Connector2"]=HSC["Con2"].getDemand()
        #Transmission
        hscResults["Transmission"]=0
        hscResultsCAPEX["Transmission"]=0
        hscResultsOPEX["Transmission"]=0
        hscResultsTot["Transmission"]=hscResultsTot["Connector2"]+hscResults["Transmission"]
        hscResultsInvest["Transmission"]=0
        hscResultsEnergy["Transmission"]=0
        #Connector 3
        hscResults["Connector3"]=0
        hscResultsCAPEX["Connector3"]=0
        hscResultsOPEX["Connector3"]=0
        hscResultsTot["Connector3"]=hscResultsTot["Transmission"]+hscResults["Connector3"]
        hscResultsInvest["Connector3"]=0
        hscResultsEnergy["Connector3"]=0
        #Distribution
        HSC["Distribution"]=hscFun.Truck(EdgesFinal["capacity"].values*1e6/365,
                                         EdgesFinal["distance"].values*weightStreetSimple,
                                         hscName["Distribution"],
                                         dfTable,
                                         costH2In=hscResults["Transmission"])
        EdgesFinal["TOTEX"]=HSC["Distribution"].getTOTEX()
        hscResults["Distribution"]=np.sum(EdgesFinal["TOTEX"]*EdgesFinal["capacity"])/totalH2Demand
        hscResultsCAPEX["Distribution"]=np.sum(HSC["Distribution"].CAPEX*EdgesFinal["capacity"])/totalH2Demand
        hscResultsOPEX["Distribution"]=np.sum(HSC["Distribution"].OPEX*EdgesFinal["capacity"])/totalH2Demand
          
        numberOfTrucks=np.sum(HSC["Distribution"].nTruck)
        print("numberOfTrucks")
    hscResultsInvest["Distribution"]=np.sum(HSC["Distribution"].getInvest())
    hscResultsTot["Distribution"]=hscResultsTot["Transmission"]+hscResults["Distribution"]
    hscResultsEnergy["Distribution"]=HSC["Distribution"].getDemand()
    #%%
    HSC["Fueling"]=hscFun.Station(FuelingNew["H2Demand_kg_d_F"], hscName["Fueling"], dfTable, costH2In=hscResults["Distribution"])
    FuelingNew["fuelingSpecCost"]=HSC["Fueling"].getTOTEX()
    
    hscResults["Fueling"]=np.sum(FuelingNew["fuelingSpecCost"]*FuelingNew["H2Demand_kg_d_F"])/np.sum(FuelingNew["H2Demand_kg_d_F"])
    hscResultsCAPEX["Fueling"]=np.sum(HSC["Fueling"].CAPEX*FuelingNew["H2Demand_kg_d_F"])/np.sum(FuelingNew["H2Demand_kg_d_F"])
    hscResultsOPEX["Fueling"]=np.sum(HSC["Fueling"].OPEX*FuelingNew["H2Demand_kg_d_F"])/np.sum(FuelingNew["H2Demand_kg_d_F"])
    hscResultsTot["Fueling"]=hscResultsTot["Distribution"]+hscResults["Fueling"]  
    hscResultsInvest["Fueling"]=np.sum(HSC["Fueling"].getInvest())
    hscResultsEnergy["Fueling"]=HSC["Fueling"].getDemand()
    #%%
    hscRes=pd.DataFrame()
    hscRes["spec. costs[€/kg]"]=hscResults
    hscRes["cum. costs[€/kg]"]=hscResultsTot
    hscRes["OPEX [€/kg]"]=hscResultsOPEX
    hscRes["CAPEX [€/kg]"]=hscResultsCAPEX     
    hscRes["Invest [Mrd. €]"]=hscResultsInvest*1e-9
    hscRes["Name"]=hscName
    hscRes["kilometer cost[€/km]"]=hscResults*specificDemand
    hscRes["scenario"]=targetCars
    hscRes["pathway"]=hscName["Transmission"]+"_"+hscName["Distribution"]
    hscRes=pd.concat([hscRes, hscResultsEnergy.T],axis=1)
    hscRes=hscRes.round(2)
    if scenario==2:
        powerInput=gpd.GeoDataFrame(HSC["Con2"].electricityPower)
        powerInput.columns=["electricityPower"]
        powerInput.geometry=Source.geometry
        powerInput["x"]=powerInput.geometry.map(lambda p:p.x).values
        powerInput["y"]=powerInput.geometry.map(lambda p:p.y).values
        if analysisType=="pipeline":
            powerInput.to_csv("20millionFCEV"+hscName["Transmission"]+hscName["Distribution"]+".csv")
        else:
            powerInput.to_csv("20millionFCEV"+hscName["Distribution"]+".csv")
    #%%  
    #%%
    if analysisType=="pipeline":
        if hscName["Distribution"]=="Pipeline":
            
            dfResults=pd.DataFrame(["%.0f" %(targetCars*1e-6)+ " Mio.",
                                    "%.0f" %totalH2Demand +" kt/year",
                                    "%.0f" %len(FuelingNew),                                    
                                    "%.0f" % sum(EdgesFinal[EdgesFinal["distribution"]==False]["weightedDistance"]) + " km",
                                    "%.0f" % sum(EdgesFinal[EdgesFinal["distribution"]]["weightedDistance"]) + " km"],
                                   index=["Number of vehicles",
                                          "Hydrogen demand",
                                          "Fueling stations",
                                          "Transmission length",
                                          "Distribution length"])
    
        else:
            dfResults=pd.DataFrame(["%.0f" %(targetCars*1e-6)+ " Mio.",
                                    "%.0f" %totalH2Demand +" kt/year",
                                    "%.0f" %len(FuelingNew),                                    
                                    "%.0f" % sum(EdgesFinal[EdgesFinal["distribution"]==False]["weightedDistance"]) + " km",
                                    "%.0f" % numberOfTrucks],
                                   index=["Number of vehicles",
                                          "Hydrogen demand",
                                          "Fueling stations",
                                          "Transmission length",
                                          "Number of Trucks"])
    else:
        dfResults=pd.DataFrame(["%.0f" %(targetCars*1e-6)+ " Mio.",
                                "%.0f" %totalH2Demand +" kt/year",
                                "%.0f" %len(FuelingNew),
                                "%.0f" % numberOfTrucks],
                                index=["Number of vehicles",
                                       "Hydrogen demand",
                                       "Fueling stations",
                                       "Number of Trucks"])
    dfResults.columns=["Scenario Results"]
    #%%
    from openpyxl import load_workbook
    pathHSC="H2MobilityResults/HSCTest.xlsx"
    book = load_workbook(pathHSC)
    
    sheetName=hscName["Transmission"]+"_"+hscName["Distribution"]+"_"  +"%.0f" %(targetCars*1e-6)
    if sheetName in book.sheetnames:
        std=book.get_sheet_by_name(sheetName)
        book.remove_sheet(std)
    writer=pd.ExcelWriter(pathHSC, engine = 'openpyxl')
    writer.book=book
    hscRes.to_excel(writer,
                    sheet_name=sheetName)
    writer.save()
    writer.close()
    toc=time.time()
    print(str(toc-tic) + " Sekunden")
    
    
    #%% Plotting function
    print("-------------- Plotting --------------")
    tic=time.time()
    fig = plt.figure(figsize=figsize)
    ax=fig.add_subplot(111)
    
    ax.set_aspect('equal')
    District.plot(ax=ax, color=bg_area, edgecolor=bg_lines, alpha=1.)
    varPlot="diameter"
    
    if analysisType=="pipeline":
        if hscName["Distribution"]=="Pipeline":
            EdgesFinal[EdgesFinal["distribution"]].plot(ax=ax, linewidth=1, color=(0, 0, 0), alpha = 1)
        else:
            EdgesFtoC=gpd.GeoDataFrame(FuelingNew["EdgesFtoC"].values, columns=["geometry"])
            EdgesFtoC.plot(ax=ax, linewidth=0.5, color="black", alpha =1)
        EdgesT=EdgesFinal[EdgesFinal["distribution"]==False]
        multLineWidth=5
        varPlot="diameter"
        rangeMax=10
        base=1000/rangeMax
        for i in range(rangeMax+1):
            i_norm=i/rangeMax
            if i == 0:
                EdgesT[EdgesT[varPlot]<base].plot(ax=ax, linewidth=multLineWidth/rangeMax, color=(i_norm, 0, 0), alpha = 1)
            elif i<rangeMax:
                EdgesT[EdgesT[varPlot].between(base*i, base*(i+1))].plot(ax=ax, linewidth=multLineWidth*i_norm, color=(i_norm, 0, 0), alpha = 1)#(1, 1-i_norm, 1-i_norm)
            else:
                EdgesT[EdgesT[varPlot]>i*base].plot(ax=ax, linewidth=multLineWidth*(i_norm), color=(i_norm, 0, 0), alpha = 1)
    
    
    if analysisType=="truck":
        EdgesFinal[EdgesFinal["distribution"]].plot(ax=ax, linewidth=0.5, color=(0, 0, 0), alpha = 1)
        
    plt.title(hscName["Storage"] + " " + hscName["Distribution"] + " for " + "%.f" %(targetCars*1e-6) + " million vehicles", fontsize=18) 
    if analysisType=="pipeline":
        Centroid[Centroid["H2Demand_kt"]>0].plot(ax=ax, marker="^", markersize=5, color="yellow")#, column="ID_S")   
    elif analysisType=="truck":
        FuelingNew.plot(ax=ax, marker=".", markersize=1, color="yellow")
        
    #FuelingNew.plot(ax=ax, marker="*", markersize=3, color="yellow")
    Source[Source["H2Production_kt"]>1e-6].plot(ax=ax, marker="*", markersize=20, color="red")#, column = "ID_S")
    
    ax.axis("off")
    
    savePath="H2MobilityResults/Plots/" + hscName["Storage"]+"_"+hscName["Transmission"]+"_"+hscName["Distribution"]+"_" +"%.0f" %(targetCars*1e-6) + ".png"

    fig.savefig(savePath,
                dpi=300,
                edgecolor=None,
                facecolor="white",
                frameon=False,
                transparent = True)
#    plt.tight_layout()
    plt.show()
    
    ##%%
    toc=time.time()
    print(str(toc-tic)+" Seconds\n")   
toctoc=time.time()
print("total Time: " + str(toctoc-tictic) + " Sekunden")
# Out:
# -------------- Preparing total Analysis --------------
# 0.6860761642456055 Sekunden
# -------------- Plotting --------------
# 34.660056829452515 Seconds
#
# -------------- Preparing total Analysis --------------
# 0.691580057144165 Sekunden
# -------------- Plotting --------------
# 131.55176711082458 Seconds
#
# total Time: 3187.3585629463196 Sekunden
